# %% [markdown]
# ## Museum Exhibition Data Validation
# <p>You are working with a local museum. The museum is about to launch a new interactive application on Roman emperors and your job is to prepare the data that it will display.</p>
# <p>The museum’s database has a table, named <code>emperors</code>, with basic information on all emperors who ruled from 1 AD onwards. You will need to clean the data before the app can launch.</p>
# <p>Your query will need to return a table that contains the following columns (with the given alias) and meets the specified requirements. You will use the data contained in the <code>emperors</code> table.</p>
# <table>
# <thead>
# <tr>
# <th style="text-align:left;">Requirements</th>
# <th style="text-align:left;">Data Type</th>
# <th style="text-align:left;">Column Alias</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:left;">Short name of the emperor in upper case (e.g., ‘AUGUSTUS‘). This is a unique name, and there should only be one entry per emperor.</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">name</td>
# </tr>
# <tr>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# </tr>
# <tr>
# <td style="text-align:left;">Full name of the emperor in lower case (e.g., ‘tiberivs caesar divi avgvsti filivs avgvstvs‘).</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">full_name</td>
# </tr>
# <tr>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# </tr>
# <tr>
# <td style="text-align:left;">Birth place in format ‘City, Province’ (with a space after the comma). If the birth city is missing but the province is known, the table should read ‘Unknown, Province’, and vice versa. If both are missing the value should simply read ‘Unknown’ (i.e., instead of 'Unknown, Unknown').</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">birthplace</td>
# </tr>
# <tr>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# </tr>
# <tr>
# <td style="text-align:left;">Age at time of death, in years (e.g., 34). In cases where either the birth or death date are missing the value should read ‘Unknown’.</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">age</td>
# </tr>
# <tr>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# </tr>
# <tr>
# <td style="text-align:left;">Length of reign, in years (e.g., 4). Calculated as the date the reign ended minus the date the reign began. In cases where the start or end date of the reign are missing the value should read ‘Unknown’.</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">reign</td>
# </tr>
# <tr>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# </tr>
# <tr>
# <td style="text-align:left;">Cause of death. Limited to ‘Assassination‘, ‘Natural Causes‘, ‘Execution‘, ‘Died in Battle‘, and ‘Suicide‘. All other causes of death should be categorized as ‘Other‘.</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">cod</td>
# </tr>
# <tr>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# <td style="text-align:left;"></td>
# </tr>
# <tr>
# <td style="text-align:left;">Era in which they ruled. Reigns that began prior to 284 AD should be categorized as ‘Principate‘, and reigns that began in 284 AD or later should be categorized as ‘Dominate‘.</td>
# <td style="text-align:left;">TEXT</td>
# <td style="text-align:left;">era</td>
# </tr>
# </tbody>
# </table>

# %%
# %%sql
# postgresql:///roman
#
# UPDATE emperors
# SET name = UPPER(name)
# Out:
# 71 rows affected.
# []

# %%
# %%sql
# postgresql:///roman
#
# UPDATE emperors
# SET full_name = LOWER(full_name)
# Out:
# 71 rows affected.
# []

# %%
# %%sql
# postgresql:///roman
# SELECT * FROM emperors
# Out:
# 71 rows affected.
# [('2', 'NERO', 'nero clavdivs caesar avgvstvs germanicvs', datetime.datetime(37, 12, 15, 0, 0, 28), datetime.datetime(68, 6, 9, 0, 0, 28), 'Antitum', 'Italia', 'Birthright', datetime.datetime(54, 10, 13, 0, 53, 28), datetime.datetime(68, 6, 9, 0, 53, 28), 'Suicide', 'Senate', 'Julio-Claudian', 'Principate', 'Antitum, Italia', '31', '14'),
#  ('3', 'GALBA', 'servivs svlpicivs galba caesar avgvstvs', datetime.datetime(2, 12, 24, 0, 0, 28), datetime.datetime(69, 1, 15, 0, 0, 28), 'Terracina', 'Italia', 'Seized Power', datetime.datetime(68, 6, 8, 0, 53, 28), datetime.datetime(69, 1, 15, 0, 53, 28), 'Assassination', 'Other Emperor', 'Flavian', 'Principate', 'Terracina, Italia', '67', '1'),
#  ('4', 'OTHO', 'marcvs salvivs otho caesar avgvstvs', datetime.datetime(32, 4, 28, 0, 0, 28), datetime.datetime(69, 4, 16, 0, 0, 28), 'Terentinum', 'Italia', 'Appointment by Praetorian Guard', datetime.datetime(69, 1, 15, 0, 53, 28), datetime.datetime(69, 4, 16, 0, 53, 28), 'Suicide', 'Other Emperor', 'Flavian', 'Principate', 'Terentinum, Italia', '37', '0'),
#  ('5', 'VITELLIUS', 'avlvs vitellivs germanicvs avgvstvs', datetime.datetime(15, 9, 24, 0, 0, 28), datetime.datetime(69, 12, 20, 0, 0, 28), 'Rome', 'Italia', 'Seized Power', datetime.datetime(69, 4, 17, 0, 53, 28), datetime.datetime(69, 12, 20, 0, 53, 28), 'Assassination', 'Other Emperor', 'Flavian', 'Principate', 'Rome, Italia', '54', '0'),
#  ('6', 'VESPASIAN', 'titvs flavivs caesar vespasianvs avgvstvs', datetime.datetime(9, 11, 17, 0, 0, 28), datetime.datetime(79, 6, 24, 0, 0, 28), 'Falacrine', 'Italia', 'Seized Power', datetime.datetime(69, 12, 21, 0, 53, 28), datetime.datetime(79, 6, 24, 0, 53, 28), 'Natural Causes', 'Disease', 'Flavian', 'Principate', 'Falacrine, Italia', '70', '10'),
#  ('25', 'GORDIAN I', 'caesar marcvs antonivs gordianvs sempronianvs africanvs avgvstvs', datetime.datetime(159, 1, 1, 0, 0, 28), datetime.datetime(238, 4, 12, 0, 0, 28), 'Unknown', 'Phrygia', 'Appointment by Senate', datetime.datetime(238, 3, 22, 0, 53, 28), datetime.datetime(238, 4, 12, 0, 53, 28), 'Suicide', 'Other Emperor', 'Gordian', 'Principate', 'Unknown, Phrygia', '79', '0'),
#  ('51', 'CONSTANTINE THE GREAT', 'caesar flavivs valerivs avrelivs constantinvs avgvstvs', datetime.datetime(272, 2, 27, 0, 0, 28), datetime.datetime(337, 5, 22, 0, 0, 28), 'Naissus', 'Moesia Superior', 'Birthright', datetime.datetime(306, 7, 25, 0, 53, 28), datetime.datetime(337, 5, 22, 0, 53, 28), 'Natural Causes', 'Disease', 'Constantinian', 'Dominate', 'Naissus, Moesia Superior', '65', '31'),
#  ('68', 'CALIGULA', 'gaivs ivlivs caesar avgvstvs germanicvs', datetime.datetime(12, 8, 31, 0, 0, 28), datetime.datetime(41, 1, 24, 0, 0, 28), 'Antitum', 'Italia', 'Birthright', datetime.datetime(37, 3, 18, 0, 53, 28), datetime.datetime(41, 1, 24, 0, 53, 28), 'Assassination', 'Senate', 'Julio-Claudian', 'Principate', 'Antitum, Italia', '29', '4'),
#  ('70', 'VITELLIUS', 'avlvs vitellivs germanicvs avgvstvs', datetime.datetime(15, 9, 24, 0, 0, 28), datetime.datetime(69, 12, 20, 0, 0, 28), 'Rome', 'Italia', 'Seized Power', datetime.datetime(69, 4, 17, 0, 53, 28), datetime.datetime(69, 12, 20, 0, 53, 28), 'Assassination', 'Other Emperor', 'Flavian', 'Principate', 'Rome, Italia', '54', '0'),
#  ('7', 'TITUS', 'titvs flavivs caesar vespasianvs avgvstvs', datetime.datetime(39, 12, 30, 0, 0, 28), datetime.datetime(81, 9, 13, 0, 0, 28), 'Rome', 'Italia', 'Birthright', datetime.datetime(79, 6, 24, 0, 53, 28), datetime.datetime(81, 9, 13, 0, 53, 28), 'Natural Causes', 'Disease', 'Flavian', 'Principate', 'Rome, Italia', '42', '2'),
#  ('8', 'DOMITIAN', 'titvs flavivs caesar domitianvs avgvstvs', datetime.datetime(51, 10, 24, 0, 0, 28), datetime.datetime(96, 9, 18, 0, 0, 28), 'Rome', 'Italia', 'Birthright', datetime.datetime(81, 9, 14, 0, 53, 28), datetime.datetime(96, 9, 18, 0, 53, 28), 'Assassination', 'Court Officials', 'Flavian', 'Principate', 'Rome, Italia', '45', '15'),
#  ('9', 'NERVA', 'marcvs cocceivs nerva caesar avgvstvs', datetime.datetime(30, 11, 8, 0, 0, 28), datetime.datetime(98, 1, 27, 0, 0, 28), 'Narni', 'Italia', 'Appointment by Senate', datetime.datetime(96, 9, 18, 0, 53, 28), datetime.datetime(98, 1, 27, 0, 53, 28), 'Natural Causes', 'Disease', 'Nerva-Antonine', 'Principate', 'Narni, Italia', '68', '2'),
#  ('10', 'TRAJAN', 'caesar marcvs vlpivs nerva traianvs avgvstvs', datetime.datetime(53, 9, 18, 0, 0, 28), datetime.datetime(117, 8, 7, 0, 0, 28), 'Italica', 'Hispania Baetica', 'Birthright', datetime.datetime(98, 1, 28, 0, 53, 28), datetime.datetime(117, 8, 7, 0, 53, 28), 'Natural Causes', 'Disease', 'Nerva-Antonine', 'Principate', 'Italica, Hispania Baetica', '64', '19'),
#  ('12', 'ANTONIUS PIUS', 'caesar titvs aelivs hadrianvs antoninvs avgvstvs pivs', datetime.datetime(86, 9, 19, 0, 0, 28), datetime.datetime(161, 3, 7, 0, 0, 28), 'Lanuvium', 'Italia', 'Birthright', datetime.datetime(138, 7, 10, 0, 53, 28), datetime.datetime(161, 3, 7, 0, 53, 28), 'Natural Causes', 'Disease', 'Nerva-Antonine', 'Principate', 'Lanuvium, Italia', '75', '23'),
#  ('42', 'PROBUS', 'caesar marcvs avrelivs probvs avgvstvs', datetime.datetime(232, 8, 19, 0, 0, 28), datetime.datetime(282, 10, 1, 0, 0, 28), 'Sirmium', 'Pannonia', 'Appointment by Army', datetime.datetime(276, 9, 15, 0, 53, 28), datetime.datetime(282, 10, 1, 0, 53, 28), 'Assassination', 'Own Army', 'Gordian', 'Principate', 'Sirmium, Pannonia', '50', '6'),
#  ('43', 'CARUS', 'caesar marcvs avrelivs carvs avgvstvs', datetime.datetime(230, 1, 1, 0, 0, 28), datetime.datetime(283, 8, 1, 0, 0, 28), 'Narbo', 'Gallia Narbonensis', 'Seized Power', datetime.datetime(282, 10, 1, 0, 53, 28), datetime.datetime(283, 8, 1, 0, 53, 28), 'Natural Causes', 'Lightning', 'Gordian', 'Principate', 'Narbo, Gallia Narbonensis', '53', '1'),
#  ('46', 'DIOCLETIAN', 'caesar gaivs avrelivs valerivs diocletianvs avgvstvs', datetime.datetime(244, 12, 22, 0, 0, 28), datetime.datetime(311, 12, 3, 0, 0, 28), 'Salona', 'Dalmatian', 'Seized Power', datetime.datetime(284, 11, 20, 0, 53, 28), datetime.datetime(305, 5, 1, 0, 53, 28), 'Natural Causes', 'Disease', 'Constantinian', 'Dominate', 'Salona, Dalmatian', '67', '21'),
#  ('47', 'MAXIMIAN', 'caesar marcvs avrelivs valerivs maximianvs avgvstvs', datetime.datetime(250, 1, 1, 0, 0, 28), datetime.datetime(310, 7, 15, 0, 0, 28), 'Sirmium', 'Pannonia', 'Appointment by Emperor', datetime.datetime(286, 4, 1, 0, 53, 28), datetime.datetime(305, 5, 1, 0, 53, 28), 'Suicide', 'Other Emperor', 'Constantinian', 'Dominate', 'Sirmium, Pannonia', '60', '19'),
#  ('49', 'GALERIUS', 'caesar galerivs valerivs maximianvs avgvstvs', datetime.datetime(260, 1, 1, 0, 0, 28), datetime.datetime(311, 5, 1, 0, 0, 28), 'Romuliana', 'Moesia Superior', 'Appointment by Emperor', datetime.datetime(305, 5, 1, 0, 53, 28), datetime.datetime(311, 5, 1, 0, 53, 28), 'Natural Causes', 'Disease', 'Constantinian', 'Dominate', 'Romuliana, Moesia Superior', '51', '6'),
#  ('50', 'CONSTANTIUS I', 'caesar gaivs flavivs valerivs constantivs avgvstvs', datetime.datetime(250, 3, 31, 0, 0, 28), datetime.datetime(306, 7, 25, 0, 0, 28), 'Dardania', 'Moesia', 'Appointment by Emperor', datetime.datetime(305, 5, 1, 0, 53, 28), datetime.datetime(306, 7, 25, 0, 53, 28), 'Natural Causes', 'Unknown', 'Constantinian', 'Dominate', 'Dardania, Moesia', '56', '1'),
#  ('11', 'HADRIAN', 'caesar pvblivs aelivs traianvs hadrianvs avgvstvs', datetime.datetime(76, 1, 24, 0, 0, 28), datetime.datetime(138, 7, 10, 0, 0, 28), 'Italica', 'Hispania Baetica', 'Birthright', datetime.datetime(117, 8, 11, 0, 53, 28), datetime.datetime(138, 7, 10, 0, 53, 28), 'Natural Causes', 'Heart Failure', 'Nerva-Antonine', 'Principate', 'Italica, Hispania Baetica', '62', '21'),
#  ('13', 'MARCUS AURELIUS', 'caesar marcvs avrelivs antoninvs avgvstvs', datetime.datetime(121, 4, 26, 0, 0, 28), datetime.datetime(180, 3, 17, 0, 0, 28), 'Rome', 'Italia', 'Birthright', datetime.datetime(161, 3, 7, 0, 53, 28), datetime.datetime(180, 3, 17, 0, 53, 28), 'Natural Causes', 'Disease', 'Nerva-Antonine', 'Principate', 'Rome, Italia', '59', '19'),
#  ('14', 'LUCIUS VERUS', 'caesar lvcivs avrelivs vervs avgvstvs', datetime.datetime(130, 12, 15, 0, 0, 28), datetime.datetime(169, 3, 15, 0, 0, 28), 'Rome', 'Italia', 'Birthright', datetime.datetime(161, 3, 7, 0, 53, 28), datetime.datetime(169, 3, 15, 0, 53, 28), 'Natural Causes', 'Disease', 'Nerva-Antonine', 'Principate', 'Rome, Italia', '39', '8'),
#  ('15', 'COMMODUS', 'caesar marcvs avrelivs commodvs antoninvs avgvstvs', datetime.datetime(161, 8, 31, 0, 0, 28), datetime.datetime(192, 12, 31, 0, 0, 28), 'Lanuvium', 'Italia', 'Birthright', datetime.datetime(177, 1, 1, 0, 53, 28), datetime.datetime(192, 12, 31, 0, 53, 28), 'Assassination', 'Praetorian Guard', 'Nerva-Antonine', 'Principate', 'Lanuvium, Italia', '31', '15'),
#  ('58', 'VETRANIO', 'caesar flavivs vetranio avgvstvs', None, datetime.datetime(356, 1, 1, 0, 0, 28), 'Unknown', 'Moesia', 'Seized Power', datetime.datetime(350, 3, 1, 0, 53, 28), datetime.datetime(350, 12, 25, 0, 53, 28), 'Other', 'Unknown', 'Constantinian', 'Dominate', 'Unknown, Moesia', 'Unknown', '0'),
#  ('19', 'CARACALLA', 'caesar marcvs avrelivs severvs antoninvs pivs avgvstvs', datetime.datetime(188, 4, 4, 0, 0, 28), datetime.datetime(217, 4, 8, 0, 0, 28), 'Lugdunum', 'Gallia Lugdunensis', 'Birthright', datetime.datetime(198, 1, 1, 0, 53, 28), datetime.datetime(217, 4, 8, 0, 53, 28), 'Assassination', 'Other Emperor', 'Severan', 'Principate', 'Lugdunum, Gallia Lugdunensis', '29', '19'),
#  ('20', 'GETA', 'caesar pvblivs septimivs geta avgvstus', datetime.datetime(189, 3, 7, 0, 0, 28), datetime.datetime(211, 12, 19, 0, 0, 28), 'Rome', 'Italia', 'Birthright', datetime.datetime(209, 1, 1, 0, 53, 28), datetime.datetime(211, 12, 26, 0, 53, 28), 'Assassination', 'Other Emperor', 'Severan', 'Principate', 'Rome, Italia', '22', '2'),
#  ('21', 'MACRINUS', 'marcvs opellivs severvs macrinvs avgvstvs pivs felix', datetime.datetime(165, 1, 1, 0, 0, 28), datetime.datetime(218, 6, 8, 0, 0, 28), 'Iol Caesarea', 'Mauretania', 'Seized Power', datetime.datetime(217, 4, 11, 0, 53, 28), datetime.datetime(218, 6, 8, 0, 53, 28), 'Execution', 'Other Emperor', 'Severan', 'Principate', 'Iol Caesarea, Mauretania', '53', '1'),
#  ('60', 'JOVIAN', 'caesar flavivs iovianvs avgvstvs', datetime.datetime(331, 1, 1, 0, 0, 28), datetime.datetime(364, 2, 17, 0, 0, 28), 'Singidunum', 'Moesia', 'Appointment by Army', datetime.datetime(363, 6, 26, 0, 53, 28), datetime.datetime(364, 2, 17, 0, 53, 28), 'Natural Causes', 'Fire', 'Constantinian', 'Dominate', 'Singidunum, Moesia', '33', '1'),
#  ('61', 'VALENTINIAN I', 'flavivs valentinianvs avgvstvs', datetime.datetime(321, 7, 3, 0, 0, 28), datetime.datetime(375, 11, 17, 0, 0, 28), 'Cibalae', 'Pannonia', 'Election', datetime.datetime(364, 2, 26, 0, 53, 28), datetime.datetime(375, 11, 17, 0, 53, 28), 'Natural Causes', 'Aneurism', 'Valentinian', 'Dominate', 'Cibalae, Pannonia', '54', '11'),
#  ('62', 'VALENS', 'flavivs ivlivs valens avgvstvs', datetime.datetime(328, 1, 1, 0, 0, 28), datetime.datetime(378, 8, 9, 0, 0, 28), 'Cibalae', 'Pannonia', 'Birthright', datetime.datetime(364, 3, 28, 0, 53, 28), datetime.datetime(378, 8, 9, 0, 53, 28), 'Died in Battle', 'Opposing Army', 'Valentinian', 'Dominate', 'Cibalae, Pannonia', '50', '14'),
#  ('63', 'GRATIAN', 'flavivs gratianvs avgvstvs', datetime.datetime(359, 4, 18, 0, 0, 28), datetime.datetime(383, 8, 25, 0, 0, 28), 'Sirmium', 'Pannonia', 'Birthright', datetime.datetime(367, 8, 4, 0, 53, 28), datetime.datetime(383, 8, 25, 0, 53, 28), 'Assassination', 'Own Army', 'Valentinian', 'Dominate', 'Sirmium, Pannonia', '24', '16'),
#  ('64', 'VALENTINIAN II', 'flavivs valentinianvs invictvs avgvstvs', datetime.datetime(371, 1, 1, 0, 0, 28), datetime.datetime(392, 5, 15, 0, 0, 28), 'Milan', 'Italia', 'Birthright', datetime.datetime(375, 11, 17, 0, 53, 28), datetime.datetime(392, 5, 15, 0, 53, 28), 'Suicide', 'Unknown', 'Valentinian', 'Dominate', 'Milan, Italia', '21', '17'),
#  ('65', 'THEODOSIUS I', 'flavivs theodosivs avgvstvs', datetime.datetime(347, 1, 11, 0, 0, 28), datetime.datetime(395, 1, 17, 0, 0, 28), 'Cauca', 'Hispania', 'Birthright', datetime.datetime(379, 1, 1, 0, 53, 28), datetime.datetime(395, 1, 17, 0, 53, 28), 'Natural Causes', 'Disease', 'Theodosian', 'Dominate', 'Cauca, Hispania', '48', '16'),
#  ('67', 'VALENS', 'flavivs ivlivs valens avgvstvs', datetime.datetime(328, 1, 1, 0, 0, 28), datetime.datetime(378, 8, 9, 0, 0, 28), 'Cibalae', 'Pannonia', 'Birthright', datetime.datetime(364, 3, 28, 0, 53, 28), datetime.datetime(378, 8, 9, 0, 53, 28), 'Died in Battle', 'Opposing Army', 'Valentinian', 'Dominate', 'Cibalae, Pannonia', '50', '14'),
#  ('66', 'MAXIMINUS II', 'caesar galerivs valerivs maximinvs avgvstvs', datetime.datetime(270, 11, 20, 0, 0, 28), datetime.datetime(313, 8, 1, 0, 0, 28), 'Unknown', 'Dacia Aureliana', 'Birthright', datetime.datetime(311, 5, 1, 0, 53, 28), datetime.datetime(313, 8, 1, 0, 53, 28), 'Execution', 'Other Emperor', 'Constantinian', 'Dominate', 'Unknown, Dacia Aureliana', '43', '2'),
#  ('28', 'GORDIAN III', 'caesar marcvs antonivs gordianvs avgvstvs', datetime.datetime(225, 1, 20, 0, 0, 28), datetime.datetime(244, 2, 11, 0, 0, 28), 'Rome', 'Italia', 'Appointment by Senate', datetime.datetime(238, 4, 22, 0, 53, 28), datetime.datetime(244, 2, 11, 0, 53, 28), 'Died in Battle', 'Opposing Army', 'Gordian', 'Principate', 'Rome, Italia', '19', '6'),
#  ('30', 'PHILIP I', 'caesar marcvs ivlivs philippvs avgvstvs', datetime.datetime(204, 1, 1, 0, 0, 28), datetime.datetime(249, 10, 1, 0, 0, 28), 'Shahba', 'Syria', 'Seized Power', datetime.datetime(244, 2, 14, 0, 53, 28), datetime.datetime(249, 10, 1, 0, 53, 28), 'Execution', 'Other Emperor', 'Gordian', 'Principate', 'Shahba, Syria', '45', '5'),
#  ('31', 'TRAJAN DECIUS', 'caesar gaivs messivs qvintvs traianvs decivs avgvstvs', datetime.datetime(201, 1, 1, 0, 0, 28), datetime.datetime(251, 6, 15, 0, 0, 28), 'Budalia', 'Pannonia Inferior', 'Appointment by Army', datetime.datetime(249, 10, 1, 0, 53, 28), datetime.datetime(251, 6, 15, 0, 53, 28), 'Died in Battle', 'Opposing Army', 'Gordian', 'Principate', 'Budalia, Pannonia Inferior', '50', '2'),
#  ('32', 'TREBONIANUS GALLUS', 'caesar gaivs vibivs trebonianvs gallvs avgvstvs', datetime.datetime(206, 1, 1, 0, 0, 28), datetime.datetime(253, 8, 15, 0, 0, 28), 'Unknown', 'Italia', 'Appointment by Army', datetime.datetime(251, 6, 15, 0, 53, 28), datetime.datetime(253, 8, 15, 0, 53, 28), 'Assassination', 'Other Emperor', 'Gordian', 'Principate', 'Unknown, Italia', '47', '2'),
#  ('34', 'AEMILIAN', 'caesar marcvs aemilivs aemilianvs avgvstvs', datetime.datetime(207, 1, 1, 0, 0, 28), datetime.datetime(253, 10, 15, 0, 0, 28), 'Unknown', 'Africa', 'Appointment by Army', datetime.datetime(253, 8, 15, 0, 53, 28), datetime.datetime(253, 10, 15, 0, 53, 28), 'Assassination', 'Other Emperor', 'Gordian', 'Principate', 'Unknown, Africa', '46', '0'),
#  ('0', 'CALIGULA', 'gaivs ivlivs caesar avgvstvs germanicvs', datetime.datetime(12, 8, 31, 0, 0, 28), datetime.datetime(41, 1, 24, 0, 0, 28), 'Antitum', 'Italia', 'Birthright', datetime.datetime(37, 3, 18, 0, 53, 28), datetime.datetime(41, 1, 24, 0, 53, 28), 'Assassination', 'Senate', 'Julio-Claudian', 'Principate', 'Antitum, Italia', '29', '4'),
#  ('1', 'CLAUDIUS', 'tiberivs clavdivs caesar avgvstvs germanicvs', datetime.datetime(9, 8, 1, 0, 0, 28), datetime.datetime(54, 10, 13, 0, 0, 28), 'Lugdunum', 'Gallia Lugdunensis', 'Birthright', datetime.datetime(41, 1, 25, 0, 53, 28), datetime.datetime(54, 10, 13, 0, 53, 28), 'Assassination', 'Wife', 'Julio-Claudian', 'Principate', 'Lugdunum, Gallia Lugdunensis', '45', '13'),
#  ('23', 'SEVERUS ALEXANDER', 'caesar marcvs avrelivs severvs alexander avgvstvs', datetime.datetime(208, 10, 1, 0, 0, 28), datetime.datetime(235, 3, 18, 0, 0, 28), 'Arca Caesarea', 'Syria', 'Birthright', datetime.datetime(222, 3, 13, 0, 53, 28), datetime.datetime(235, 3, 18, 0, 53, 28), 'Assassination', 'Own Army', 'Severan', 'Principate', 'Arca Caesarea, Syria', '27', '13'),
#  ('33', 'HOSTILIAN', 'caesar caivs valens hostilianvs messivs qvintvs avgvstvs', datetime.datetime(230, 1, 1, 0, 0, 28), datetime.datetime(251, 10, 1, 0, 0, 28), 'Sirmium', 'Pannonia', 'Birthright', datetime.datetime(251, 6, 15, 0, 53, 28), datetime.datetime(251, 10, 1, 0, 53, 28), 'Natural Causes', 'Disease', 'Gordian', 'Principate', 'Sirmium, Pannonia', '21', '0'),
#  ('37', 'CLAUDIUS GOTHICUS', 'caesar marcvs avrelivs clavdivs avgvstvs', datetime.datetime(213, 5, 10, 0, 0, 28), datetime.datetime(270, 1, 15, 0, 0, 28), 'Sirmium', 'Pannonia', 'Seized Power', datetime.datetime(268, 9, 15, 0, 53, 28), datetime.datetime(270, 1, 15, 0, 53, 28), 'Natural Causes', 'Disease', 'Gordian', 'Principate', 'Sirmium, Pannonia', '57', '2'),
#  ('26', 'GORDIAN II', 'caesar marcvs antonivs gordianvs sempronianvs romanvs africanvs avgvstvs', datetime.datetime(192, 1, 1, 0, 0, 28), datetime.datetime(238, 4, 12, 0, 0, 28), 'Unknown', 'Unknown', 'Appointment by Senate', datetime.datetime(238, 3, 22, 0, 53, 28), datetime.datetime(238, 4, 12, 0, 53, 28), 'Execution', 'Other Emperor', 'Gordian', 'Principate', 'Unknown', '46', '0'),
#  ('27', 'BALBINUS', 'caesar decimvs caelivs calvinvs balbinvs pivs avgvstvs', datetime.datetime(178, 1, 1, 0, 0, 28), datetime.datetime(238, 7, 29, 0, 0, 28), 'Unknown', 'Unknown', 'Appointment by Senate', datetime.datetime(238, 4, 22, 0, 53, 28), datetime.datetime(238, 7, 29, 0, 53, 28), 'Assassination', 'Praetorian Guard', 'Gordian', 'Principate', 'Unknown', '60', '0'),
#  ('29', 'PUPIENUS', 'caesar marcvs clodivs pvpienvs maximvs avgvstvs', datetime.datetime(178, 1, 1, 0, 0, 28), datetime.datetime(238, 7, 29, 0, 0, 28), 'Unknown', 'Unknown', 'Appointment by Senate', datetime.datetime(238, 4, 22, 0, 53, 28), datetime.datetime(238, 7, 29, 0, 53, 28), 'Assassination', 'Praetorian Guard', 'Gordian', 'Principate', 'Unknown', '60', '0'),
#  ('36', 'GALLIENUS', 'caesar pvblivs licinivs egnativs gallienvs avgvstvs', datetime.datetime(218, 1, 1, 0, 0, 28), datetime.datetime(268, 9, 15, 0, 0, 28), 'Unknown', 'Unknown', 'Birthright', datetime.datetime(253, 10, 15, 0, 53, 28), datetime.datetime(268, 9, 15, 0, 53, 28), 'Assassination', 'Own Army', 'Gordian', 'Principate', 'Unknown', '50', '15'),
#  ('52', 'MAXENTIUS', 'marcvs avrelivs valerivs maxentivs avgvstvs', datetime.datetime(278, 1, 1, 0, 0, 28), datetime.datetime(312, 10, 8, 0, 0, 28), 'Unknown', 'Unknown', 'Birthright', datetime.datetime(306, 10, 8, 0, 53, 28), datetime.datetime(312, 10, 8, 0, 53, 28), 'Execution', 'Other Emperor', 'Constantinian', 'Dominate', 'Unknown', '34', '6'),
#  ('41', 'FLORIAN', 'caesar marcvs annivs florianvs avgvstvs', None, datetime.datetime(276, 9, 15, 0, 0, 28), 'Unknown', 'Unknown', 'Birthright', datetime.datetime(276, 6, 15, 0, 53, 28), datetime.datetime(276, 9, 15, 0, 53, 28), 'Assassination', 'Own Army', 'Gordian', 'Principate', 'Unknown', 'Unknown', '0'),
#  ('44', 'CARINUS', 'caesar marcvs avrelivs carinvs avgvstvs', None, datetime.datetime(285, 8, 1, 0, 0, 28), 'Unknown', 'Unknown', 'Birthright', datetime.datetime(283, 8, 1, 0, 53, 28), datetime.datetime(285, 8, 1, 0, 53, 28), 'Died in Battle', 'Opposing Army', 'Gordian', 'Principate', 'Unknown', 'Unknown', '2'),
#  ('48', 'SEVERUS II', 'flavivs valerivs severvs avgvstvs', None, datetime.datetime(307, 9, 16, 0, 0, 28), 'Unknown', 'Unknown', 'Appointment by Emperor', datetime.datetime(305, 5, 1, 0, 53, 28), datetime.datetime(307, 9, 16, 0, 53, 28), 'Assassination', 'Other Emperor', 'Constantinian', 'Dominate', 'Unknown', 'Unknown', '2'),
#  ('22', 'ELAGABALUS', 'marcvs avrelivs antoninvs avgvstvs', datetime.datetime(203, 1, 1, 0, 0, 28), datetime.datetime(222, 3, 11, 0, 0, 28), 'Emesa', 'Syria', 'Birthright', datetime.datetime(218, 6, 8, 0, 53, 28), datetime.datetime(222, 3, 11, 0, 53, 28), 'Assassination', 'Praetorian Guard', 'Severan', 'Principate', 'Emesa, Syria', '19', '4'),
#  ('39', 'AURELIAN', 'caesar lvcivs domitivs avrelianvs avgvstvs', datetime.datetime(214, 9, 9, 0, 0, 28), datetime.datetime(275, 9, 15, 0, 0, 28), 'Sirmium', 'Pannonia', 'Appointment by Army', datetime.datetime(270, 9, 15, 0, 53, 28), datetime.datetime(275, 9, 15, 0, 53, 28), 'Assassination', 'Praetorian Guard', 'Gordian', 'Principate', 'Sirmium, Pannonia', '61', '5'),
#  ('40', 'TACITUS', 'caesar marcvs clavdivs\xa0tacitvs avgvstvs', datetime.datetime(200, 1, 1, 0, 0, 28), datetime.datetime(276, 6, 15, 0, 0, 28), 'Interamna Nahars', 'Italia', 'Appointment by Senate', datetime.datetime(275, 9, 25, 0, 53, 28), datetime.datetime(276, 6, 15, 0, 53, 28), 'Natural Causes', 'Disease', 'Gordian', 'Principate', 'Interamna Nahars, Italia', '76', '1'),
#  ('24', 'MAXIMINUS I', 'caesar gaivs ivlivs vervs maximinvs avgvstvs', datetime.datetime(173, 1, 1, 0, 0, 28), datetime.datetime(238, 6, 15, 0, 0, 28), 'Unknown', 'Thrace', 'Appointment by Praetorian Guard', datetime.datetime(235, 3, 20, 0, 53, 28), datetime.datetime(238, 6, 15, 0, 53, 28), 'Assassination', 'Praetorian Guard', 'Gordian', 'Principate', 'Unknown, Thrace', '65', '3'),
#  ('54', 'MAXIMINUS II', 'caesar galerivs valerivs maximinvs avgvstvs', datetime.datetime(270, 11, 20, 0, 0, 28), datetime.datetime(313, 8, 1, 0, 0, 28), 'Unknown', 'Dacia Aureliana', 'Birthright', datetime.datetime(311, 5, 1, 0, 53, 28), datetime.datetime(313, 8, 1, 0, 53, 28), 'Execution', 'Other Emperor', 'Constantinian', 'Dominate', 'Unknown, Dacia Aureliana', '43', '2'),
#  ('56', 'CONSTANS', 'caesar flavivs ivlivs constans avgvstvs', datetime.datetime(320, 1, 1, 0, 0, 28), datetime.datetime(350, 2, 14, 0, 0, 28), 'Unknown', 'Moesia', 'Birthright', datetime.datetime(337, 5, 22, 0, 53, 28), datetime.datetime(350, 2, 14, 0, 53, 28), 'Assassination', 'Usurper', 'Constantinian', 'Dominate', 'Unknown, Moesia', '30', '13'),
#  ('53', 'LUCINIUS I', 'caesar gaivs valerivs licinivs avgvstvs', datetime.datetime(250, 1, 1, 0, 0, 28), datetime.datetime(325, 3, 1, 0, 0, 28), 'Felix Romuliana', 'Moesia Superior', 'Birthright', datetime.datetime(308, 11, 11, 0, 53, 28), datetime.datetime(324, 9, 18, 0, 53, 28), 'Execution', 'Other Emperor', 'Constantinian', 'Dominate', 'Felix Romuliana, Moesia Superior', '75', '16'),
#  ('55', 'CONSTANTINE II', 'caesar flavivs clavdivs constantinvs avgvstvs', datetime.datetime(316, 2, 1, 0, 0, 28), datetime.datetime(340, 1, 1, 0, 0, 28), 'Arelate', 'Gallia Narbonensis', 'Birthright', datetime.datetime(337, 5, 22, 0, 53, 28), datetime.datetime(340, 1, 1, 0, 53, 28), 'Execution', 'Other Emperor', 'Constantinian', 'Dominate', 'Arelate, Gallia Narbonensis', '24', '3'),
#  ('57', 'CONSANTIUS II', 'caesar flavivs ivlivs constantivs avgvstvs', datetime.datetime(317, 8, 7, 0, 0, 28), datetime.datetime(361, 11, 3, 0, 0, 28), 'Sirmium', 'Pannonia', 'Birthright', datetime.datetime(337, 5, 22, 0, 53, 28), datetime.datetime(361, 11, 3, 0, 53, 28), 'Natural Causes', 'Disease', 'Constantinian', 'Dominate', 'Sirmium, Pannonia', '44', '24'),
#  ('59', 'JULIAN', 'caesar flavivs clavdivs ivlianvs avgvstvs', datetime.datetime(331, 7, 1, 0, 0, 28), datetime.datetime(363, 6, 26, 0, 0, 28), 'Constantinople', 'Thrace', 'Birthright', datetime.datetime(360, 2, 14, 0, 53, 28), datetime.datetime(363, 6, 26, 0, 53, 28), 'Died in Battle', 'Opposing Army', 'Constantinian', 'Dominate', 'Constantinople, Thrace', '32', '3'),
#  ('16', 'PERTINAX', 'caesar pvblivs helvivs pertinax avgvstvs', datetime.datetime(126, 8, 1, 0, 0, 28), datetime.datetime(193, 3, 28, 0, 0, 28), 'Alba', 'Italia', 'Appointment by Praetorian Guard', datetime.datetime(193, 1, 1, 0, 53, 28), datetime.datetime(193, 3, 28, 0, 53, 28), 'Assassination', 'Praetorian Guard', 'Severan', 'Principate', 'Alba, Italia', '67', '0'),
#  ('17', 'DIDIUS JULIANUS', 'caesar marcvs didivs severvs ivlianvs avgvstvs', datetime.datetime(133, 1, 30, 0, 0, 28), datetime.datetime(193, 7, 1, 0, 0, 28), 'Milan', 'Italia', 'Purchase', datetime.datetime(193, 3, 28, 0, 53, 28), datetime.datetime(193, 7, 1, 0, 53, 28), 'Execution', 'Senate', 'Severan', 'Principate', 'Milan, Italia', '60', '0'),
#  ('18', 'SEPTIMUS SEVERUS', 'caesar lvcivs septimivs severvs pertinax avgvstvs', datetime.datetime(145, 4, 11, 0, 0, 28), datetime.datetime(211, 2, 4, 0, 0, 28), 'Leptis Magna', 'Libya', 'Seized Power', datetime.datetime(193, 4, 9, 0, 53, 28), datetime.datetime(211, 2, 4, 0, 53, 28), 'Natural Causes', 'Disease', 'Severan', 'Principate', 'Leptis Magna, Libya', '66', '18'),
#  ('38', 'QUINTILLUS', 'caesar marcvs avrelivs clavdivs qvintillvs avgvstvs', datetime.datetime(212, 1, 1, 0, 0, 28), datetime.datetime(270, 4, 15, 0, 0, 28), 'Sirmium', 'Pannonia', 'Birthright', datetime.datetime(270, 1, 15, 0, 53, 28), datetime.datetime(270, 4, 15, 0, 53, 28), 'Other', 'Unknown', 'Gordian', 'Principate', 'Sirmium, Pannonia', '58', '0'),
#  ('35', 'VALERIAN', 'caesar pvblivs licinivs valerianvs avgvstvs', datetime.datetime(195, 1, 1, 0, 0, 28), datetime.datetime(264, 1, 1, 0, 0, 28), 'Unknown', 'Unknown', 'Appointment by Army', datetime.datetime(253, 10, 15, 0, 53, 28), datetime.datetime(260, 1, 1, 0, 53, 28), 'Other', 'Opposing Army', 'Gordian', 'Principate', 'Unknown', '69', '7'),
#  ('45', 'NUMERIAN', 'caesar marcvs avrelivs nvmerivs nvmerianvs avgvstvs', None, datetime.datetime(284, 11, 20, 0, 0, 28), 'Unknown', 'Unknown', 'Birthright', datetime.datetime(283, 8, 1, 0, 53, 28), datetime.datetime(284, 11, 20, 0, 53, 28), 'Other', 'Unknown', 'Gordian', 'Principate', 'Unknown', 'Unknown', '1'),
#  ('69', 'NUMERIAN', 'caesar marcvs avrelivs nvmerivs nvmerianvs avgvstvs', None, datetime.datetime(284, 11, 20, 0, 0, 28), 'Unknown', 'Unknown', 'Birthright', datetime.datetime(283, 8, 1, 0, 53, 28), datetime.datetime(284, 11, 20, 0, 53, 28), 'Other', 'Unknown', 'Gordian', 'Principate', 'Unknown', 'Unknown', '1')]

# %%
# %%sql
# postgresql:///roman
#
# SELECT DISTINCT name, full_name from emperors
# Out:
# 66 rows affected.
# [('SEVERUS ALEXANDER', 'caesar marcvs avrelivs severvs alexander avgvstvs'),
#  ('FLORIAN', 'caesar marcvs annivs florianvs avgvstvs'),
#  ('MACRINUS', 'marcvs opellivs severvs macrinvs avgvstvs pivs felix'),
#  ('BALBINUS', 'caesar decimvs caelivs calvinvs balbinvs pivs avgvstvs'),
#  ('TACITUS', 'caesar marcvs clavdivs\xa0tacitvs avgvstvs'),
#  ('CARUS', 'caesar marcvs avrelivs carvs avgvstvs'),
#  ('GORDIAN II', 'caesar marcvs antonivs gordianvs sempronianvs romanvs africanvs avgvstvs'),
#  ('GORDIAN I', 'caesar marcvs antonivs gordianvs sempronianvs africanvs avgvstvs'),
#  ('SEVERUS II', 'flavivs valerivs severvs avgvstvs'),
#  ('VALENTINIAN II', 'flavivs valentinianvs invictvs avgvstvs'),
#  ('MAXIMINUS II', 'caesar galerivs valerivs maximinvs avgvstvs'),
#  ('AURELIAN', 'caesar lvcivs domitivs avrelianvs avgvstvs'),
#  ('HOSTILIAN', 'caesar caivs valens hostilianvs messivs qvintvs avgvstvs'),
#  ('CONSTANTINE THE GREAT', 'caesar flavivs valerivs avrelivs constantinvs avgvstvs'),
#  ('CARACALLA', 'caesar marcvs avrelivs severvs antoninvs pivs avgvstvs'),
#  ('NUMERIAN', 'caesar marcvs avrelivs nvmerivs nvmerianvs avgvstvs'),
#  ('CONSTANTINE II', 'caesar flavivs clavdivs constantinvs avgvstvs'),
#  ('MARCUS AURELIUS', 'caesar marcvs avrelivs antoninvs avgvstvs'),
#  ('JULIAN', 'caesar flavivs clavdivs ivlianvs avgvstvs'),
#  ('CLAUDIUS GOTHICUS', 'caesar marcvs avrelivs clavdivs avgvstvs'),
#  ('CARINUS', 'caesar marcvs avrelivs carinvs avgvstvs'),
#  ('VITELLIUS', 'avlvs vitellivs germanicvs avgvstvs'),
#  ('DIOCLETIAN', 'caesar gaivs avrelivs valerivs diocletianvs avgvstvs'),
#  ('MAXIMINUS I', 'caesar gaivs ivlivs vervs maximinvs avgvstvs'),
#  ('CONSTANTIUS I', 'caesar gaivs flavivs valerivs constantivs avgvstvs'),
#  ('VALENTINIAN I', 'flavivs valentinianvs avgvstvs'),
#  ('TREBONIANUS GALLUS', 'caesar gaivs vibivs trebonianvs gallvs avgvstvs'),
#  ('MAXENTIUS', 'marcvs avrelivs valerivs maxentivs avgvstvs'),
#  ('QUINTILLUS', 'caesar marcvs avrelivs clavdivs qvintillvs avgvstvs'),
#  ('NERO', 'nero clavdivs caesar avgvstvs germanicvs'),
#  ('TRAJAN', 'caesar marcvs vlpivs nerva traianvs avgvstvs'),
#  ('TITUS', 'titvs flavivs caesar vespasianvs avgvstvs'),
#  ('MAXIMIAN', 'caesar marcvs avrelivs valerivs maximianvs avgvstvs'),
#  ('GRATIAN', 'flavivs gratianvs avgvstvs'),
#  ('VALERIAN', 'caesar pvblivs licinivs valerianvs avgvstvs'),
#  ('ELAGABALUS', 'marcvs avrelivs antoninvs avgvstvs'),
#  ('GALLIENUS', 'caesar pvblivs licinivs egnativs gallienvs avgvstvs'),
#  ('CONSTANS', 'caesar flavivs ivlivs constans avgvstvs'),
#  ('PUPIENUS', 'caesar marcvs clodivs pvpienvs maximvs avgvstvs'),
#  ('HADRIAN', 'caesar pvblivs aelivs traianvs hadrianvs avgvstvs'),
#  ('NERVA', 'marcvs cocceivs nerva caesar avgvstvs'),
#  ('PERTINAX', 'caesar pvblivs helvivs pertinax avgvstvs'),
#  ('VESPASIAN', 'titvs flavivs caesar vespasianvs avgvstvs'),
#  ('TRAJAN DECIUS', 'caesar gaivs messivs qvintvs traianvs decivs avgvstvs'),
#  ('LUCINIUS I', 'caesar gaivs valerivs licinivs avgvstvs'),
#  ('PROBUS', 'caesar marcvs avrelivs probvs avgvstvs'),
#  ('LUCIUS VERUS', 'caesar lvcivs avrelivs vervs avgvstvs'),
#  ('GALERIUS', 'caesar galerivs valerivs maximianvs avgvstvs'),
#  ('SEPTIMUS SEVERUS', 'caesar lvcivs septimivs severvs pertinax avgvstvs'),
#  ('COMMODUS', 'caesar marcvs avrelivs commodvs antoninvs avgvstvs'),
#  ('OTHO', 'marcvs salvivs otho caesar avgvstvs'),
#  ('VALENS', 'flavivs ivlivs valens avgvstvs'),
#  ('CLAUDIUS', 'tiberivs clavdivs caesar avgvstvs germanicvs'),
#  ('ANTONIUS PIUS', 'caesar titvs aelivs hadrianvs antoninvs avgvstvs pivs'),
#  ('DIDIUS JULIANUS', 'caesar marcvs didivs severvs ivlianvs avgvstvs'),
#  ('JOVIAN', 'caesar flavivs iovianvs avgvstvs'),
#  ('CONSANTIUS II', 'caesar flavivs ivlivs constantivs avgvstvs'),
#  ('THEODOSIUS I', 'flavivs theodosivs avgvstvs'),
#  ('CALIGULA', 'gaivs ivlivs caesar avgvstvs germanicvs'),
#  ('VETRANIO', 'caesar flavivs vetranio avgvstvs'),
#  ('GALBA', 'servivs svlpicivs galba caesar avgvstvs'),
#  ('PHILIP I', 'caesar marcvs ivlivs philippvs avgvstvs'),
#  ('GETA', 'caesar pvblivs septimivs geta avgvstus'),
#  ('GORDIAN III', 'caesar marcvs antonivs gordianvs avgvstvs'),
#  ('AEMILIAN', 'caesar marcvs aemilivs aemilianvs avgvstvs'),
#  ('DOMITIAN', 'titvs flavivs caesar domitianvs avgvstvs')]

# %%
# %%sql
# postgresql:///roman
#
# ALTER TABLE emperors
# ADD COLUMN birthplace text
# Out:
# (psycopg2.errors.DuplicateColumn) column "birthplace" of relation "emperors" already exists
#
# [SQL: ALTER TABLE emperors
# ADD COLUMN birthplace text]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# %%sql
# postgresql:///roman
#
# UPDATE emperors
# SET birthplace = con
# Out:
# (psycopg2.errors.UndefinedColumn) column "con" does not exist
# LINE 2: SET birthplace = con
#                          ^
#
# [SQL: UPDATE emperors
# SET birthplace = con]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# %%sql
# postgresql:///roman
#
# ALTER TABLE emperors
# ALTER COLUMN death
# type timestamp without time zone
# USING death::timestamp with time zone
# Out:
# Done.
# []

# %%
# %%sql
# postgresql:///roman
#
# UPDATE emperors
# SET birth_city = 'Unknown'
# WHERE birth_city IS NULL
# Out:
# 0 rows affected.
# []

# %%
# %%sql
# postgresql:///roman
#
# UPDATE emperors
# SET birth_province = 'Unknown'
# WHERE birth_province IS NULL
# Out:
# 0 rows affected.
# []

# %%
# %%sql
# postgresql:///roman
#
# UPDATE emperors
# SET birthplace = CONCAT(birth_city, ', ', birth_province)
# Out:
# 71 rows affected.
# []

# %%
# %%sql
# postgresql:///roman
#
# UPDATE emperors
# SET birthplace = 'Unknown'
# WHERE birthplace = 'Unknown, Unknown'
# Out:
# 11 rows affected.
# []

# %%
# %%sql
# postgresql:///roman
#
# ALTER TABLE emperors
# ALTER COLUMN death
# type timestamp without time zone
# USING death::timestamp with time zone
# Out:
# Done.
# []

# %%
# %%sql
# postgresql:///roman
#
# ALTER TABLE emperors
# ALTER COLUMN birth
# type timestamp without time zone
# USING birth::timestamp with time zone
# Out:
# Done.
# []

# %%
# %%sql
# postgresql:///roman
#
# ALTER TABLE emperors
# ADD COLUMN age text
# Out:
# (psycopg2.errors.DuplicateColumn) column "age" of relation "emperors" already exists
#
# [SQL: ALTER TABLE emperors
# ADD COLUMN age text]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# %%sql
# postgresql:///roman
#
# UPDATE emperors
# SET age = EXTRACT(YEAR FROM death) - EXTRACT(YEAR FROM birth)
# Out:
# 71 rows affected.
# []

# %%
# %%sql
# postgresql:///roman
#
# UPDATE emperors
# SET age = EXTRACT(YEAR FROM death) - EXTRACT(YEAR FROM birth)
# Out:
# 71 rows affected.
# []

# %%
# %%sql
# postgresql:///roman
#
#
# UPDATE emperors
# SET age = 'Unknown'
# where age is null
# Out:
# 6 rows affected.
# []

# %%
# %%sql
# postgresql:///roman
#
# select * from emperors
# Out:
# 71 rows affected.
# [('2', 'NERO', 'nero clavdivs caesar avgvstvs germanicvs', datetime.datetime(37, 12, 15, 0, 0, 28), datetime.datetime(68, 6, 9, 0, 0, 28), 'Antitum', 'Italia', 'Birthright', datetime.datetime(54, 10, 13, 0, 53, 28), datetime.datetime(68, 6, 9, 0, 53, 28), 'Suicide', 'Senate', 'Julio-Claudian', 'Principate', 'Antitum, Italia', '31', '14'),
#  ('3', 'GALBA', 'servivs svlpicivs galba caesar avgvstvs', datetime.datetime(2, 12, 24, 0, 0, 28), datetime.datetime(69, 1, 15, 0, 0, 28), 'Terracina', 'Italia', 'Seized Power', datetime.datetime(68, 6, 8, 0, 53, 28), datetime.datetime(69, 1, 15, 0, 53, 28), 'Assassination', 'Other Emperor', 'Flavian', 'Principate', 'Terracina, Italia', '67', '1'),
#  ('4', 'OTHO', 'marcvs salvivs otho caesar avgvstvs', datetime.datetime(32, 4, 28, 0, 0, 28), datetime.datetime(69, 4, 16, 0, 0, 28), 'Terentinum', 'Italia', 'Appointment by Praetorian Guard', datetime.datetime(69, 1, 15, 0, 53, 28), datetime.datetime(69, 4, 16, 0, 53, 28), 'Suicide', 'Other Emperor', 'Flavian', 'Principate', 'Terentinum, Italia', '37', '0'),
#  ('5', 'VITELLIUS', 'avlvs vitellivs germanicvs avgvstvs', datetime.datetime(15, 9, 24, 0, 0, 28), datetime.datetime(69, 12, 20, 0, 0, 28), 'Rome', 'Italia', 'Seized Power', datetime.datetime(69, 4, 17, 0, 53, 28), datetime.datetime(69, 12, 20, 0, 53, 28), 'Assassination', 'Other Emperor', 'Flavian', 'Principate', 'Rome, Italia', '54', '0'),
#  ('6', 'VESPASIAN', 'titvs flavivs caesar vespasianvs avgvstvs', datetime.datetime(9, 11, 17, 0, 0, 28), datetime.datetime(79, 6, 24, 0, 0, 28), 'Falacrine', 'Italia', 'Seized Power', datetime.datetime(69, 12, 21, 0, 53, 28), datetime.datetime(79, 6, 24, 0, 53, 28), 'Natural Causes', 'Disease', 'Flavian', 'Principate', 'Falacrine, Italia', '70', '10'),
#  ('25', 'GORDIAN I', 'caesar marcvs antonivs gordianvs sempronianvs africanvs avgvstvs', datetime.datetime(159, 1, 1, 0, 0, 28), datetime.datetime(238, 4, 12, 0, 0, 28), 'Unknown', 'Phrygia', 'Appointment by Senate', datetime.datetime(238, 3, 22, 0, 53, 28), datetime.datetime(238, 4, 12, 0, 53, 28), 'Suicide', 'Other Emperor', 'Gordian', 'Principate', 'Unknown, Phrygia', '79', '0'),
#  ('51', 'CONSTANTINE THE GREAT', 'caesar flavivs valerivs avrelivs constantinvs avgvstvs', datetime.datetime(272, 2, 27, 0, 0, 28), datetime.datetime(337, 5, 22, 0, 0, 28), 'Naissus', 'Moesia Superior', 'Birthright', datetime.datetime(306, 7, 25, 0, 53, 28), datetime.datetime(337, 5, 22, 0, 53, 28), 'Natural Causes', 'Disease', 'Constantinian', 'Dominate', 'Naissus, Moesia Superior', '65', '31'),
#  ('68', 'CALIGULA', 'gaivs ivlivs caesar avgvstvs germanicvs', datetime.datetime(12, 8, 31, 0, 0, 28), datetime.datetime(41, 1, 24, 0, 0, 28), 'Antitum', 'Italia', 'Birthright', datetime.datetime(37, 3, 18, 0, 53, 28), datetime.datetime(41, 1, 24, 0, 53, 28), 'Assassination', 'Senate', 'Julio-Claudian', 'Principate', 'Antitum, Italia', '29', '4'),
#  ('70', 'VITELLIUS', 'avlvs vitellivs germanicvs avgvstvs', datetime.datetime(15, 9, 24, 0, 0, 28), datetime.datetime(69, 12, 20, 0, 0, 28), 'Rome', 'Italia', 'Seized Power', datetime.datetime(69, 4, 17, 0, 53, 28), datetime.datetime(69, 12, 20, 0, 53, 28), 'Assassination', 'Other Emperor', 'Flavian', 'Principate', 'Rome, Italia', '54', '0'),
#  ('7', 'TITUS', 'titvs flavivs caesar vespasianvs avgvstvs', datetime.datetime(39, 12, 30, 0, 0, 28), datetime.datetime(81, 9, 13, 0, 0, 28), 'Rome', 'Italia', 'Birthright', datetime.datetime(79, 6, 24, 0, 53, 28), datetime.datetime(81, 9, 13, 0, 53, 28), 'Natural Causes', 'Disease', 'Flavian', 'Principate', 'Rome, Italia', '42', '2'),
#  ('8', 'DOMITIAN', 'titvs flavivs caesar domitianvs avgvstvs', datetime.datetime(51, 10, 24, 0, 0, 28), datetime.datetime(96, 9, 18, 0, 0, 28), 'Rome', 'Italia', 'Birthright', datetime.datetime(81, 9, 14, 0, 53, 28), datetime.datetime(96, 9, 18, 0, 53, 28), 'Assassination', 'Court Officials', 'Flavian', 'Principate', 'Rome, Italia', '45', '15'),
#  ('9', 'NERVA', 'marcvs cocceivs nerva caesar avgvstvs', datetime.datetime(30, 11, 8, 0, 0, 28), datetime.datetime(98, 1, 27, 0, 0, 28), 'Narni', 'Italia', 'Appointment by Senate', datetime.datetime(96, 9, 18, 0, 53, 28), datetime.datetime(98, 1, 27, 0, 53, 28), 'Natural Causes', 'Disease', 'Nerva-Antonine', 'Principate', 'Narni, Italia', '68', '2'),
#  ('10', 'TRAJAN', 'caesar marcvs vlpivs nerva traianvs avgvstvs', datetime.datetime(53, 9, 18, 0, 0, 28), datetime.datetime(117, 8, 7, 0, 0, 28), 'Italica', 'Hispania Baetica', 'Birthright', datetime.datetime(98, 1, 28, 0, 53, 28), datetime.datetime(117, 8, 7, 0, 53, 28), 'Natural Causes', 'Disease', 'Nerva-Antonine', 'Principate', 'Italica, Hispania Baetica', '64', '19'),
#  ('12', 'ANTONIUS PIUS', 'caesar titvs aelivs hadrianvs antoninvs avgvstvs pivs', datetime.datetime(86, 9, 19, 0, 0, 28), datetime.datetime(161, 3, 7, 0, 0, 28), 'Lanuvium', 'Italia', 'Birthright', datetime.datetime(138, 7, 10, 0, 53, 28), datetime.datetime(161, 3, 7, 0, 53, 28), 'Natural Causes', 'Disease', 'Nerva-Antonine', 'Principate', 'Lanuvium, Italia', '75', '23'),
#  ('42', 'PROBUS', 'caesar marcvs avrelivs probvs avgvstvs', datetime.datetime(232, 8, 19, 0, 0, 28), datetime.datetime(282, 10, 1, 0, 0, 28), 'Sirmium', 'Pannonia', 'Appointment by Army', datetime.datetime(276, 9, 15, 0, 53, 28), datetime.datetime(282, 10, 1, 0, 53, 28), 'Assassination', 'Own Army', 'Gordian', 'Principate', 'Sirmium, Pannonia', '50', '6'),
#  ('43', 'CARUS', 'caesar marcvs avrelivs carvs avgvstvs', datetime.datetime(230, 1, 1, 0, 0, 28), datetime.datetime(283, 8, 1, 0, 0, 28), 'Narbo', 'Gallia Narbonensis', 'Seized Power', datetime.datetime(282, 10, 1, 0, 53, 28), datetime.datetime(283, 8, 1, 0, 53, 28), 'Natural Causes', 'Lightning', 'Gordian', 'Principate', 'Narbo, Gallia Narbonensis', '53', '1'),
#  ('46', 'DIOCLETIAN', 'caesar gaivs avrelivs valerivs diocletianvs avgvstvs', datetime.datetime(244, 12, 22, 0, 0, 28), datetime.datetime(311, 12, 3, 0, 0, 28), 'Salona', 'Dalmatian', 'Seized Power', datetime.datetime(284, 11, 20, 0, 53, 28), datetime.datetime(305, 5, 1, 0, 53, 28), 'Natural Causes', 'Disease', 'Constantinian', 'Dominate', 'Salona, Dalmatian', '67', '21'),
#  ('47', 'MAXIMIAN', 'caesar marcvs avrelivs valerivs maximianvs avgvstvs', datetime.datetime(250, 1, 1, 0, 0, 28), datetime.datetime(310, 7, 15, 0, 0, 28), 'Sirmium', 'Pannonia', 'Appointment by Emperor', datetime.datetime(286, 4, 1, 0, 53, 28), datetime.datetime(305, 5, 1, 0, 53, 28), 'Suicide', 'Other Emperor', 'Constantinian', 'Dominate', 'Sirmium, Pannonia', '60', '19'),
#  ('49', 'GALERIUS', 'caesar galerivs valerivs maximianvs avgvstvs', datetime.datetime(260, 1, 1, 0, 0, 28), datetime.datetime(311, 5, 1, 0, 0, 28), 'Romuliana', 'Moesia Superior', 'Appointment by Emperor', datetime.datetime(305, 5, 1, 0, 53, 28), datetime.datetime(311, 5, 1, 0, 53, 28), 'Natural Causes', 'Disease', 'Constantinian', 'Dominate', 'Romuliana, Moesia Superior', '51', '6'),
#  ('50', 'CONSTANTIUS I', 'caesar gaivs flavivs valerivs constantivs avgvstvs', datetime.datetime(250, 3, 31, 0, 0, 28), datetime.datetime(306, 7, 25, 0, 0, 28), 'Dardania', 'Moesia', 'Appointment by Emperor', datetime.datetime(305, 5, 1, 0, 53, 28), datetime.datetime(306, 7, 25, 0, 53, 28), 'Natural Causes', 'Unknown', 'Constantinian', 'Dominate', 'Dardania, Moesia', '56', '1'),
#  ('11', 'HADRIAN', 'caesar pvblivs aelivs traianvs hadrianvs avgvstvs', datetime.datetime(76, 1, 24, 0, 0, 28), datetime.datetime(138, 7, 10, 0, 0, 28), 'Italica', 'Hispania Baetica', 'Birthright', datetime.datetime(117, 8, 11, 0, 53, 28), datetime.datetime(138, 7, 10, 0, 53, 28), 'Natural Causes', 'Heart Failure', 'Nerva-Antonine', 'Principate', 'Italica, Hispania Baetica', '62', '21'),
#  ('13', 'MARCUS AURELIUS', 'caesar marcvs avrelivs antoninvs avgvstvs', datetime.datetime(121, 4, 26, 0, 0, 28), datetime.datetime(180, 3, 17, 0, 0, 28), 'Rome', 'Italia', 'Birthright', datetime.datetime(161, 3, 7, 0, 53, 28), datetime.datetime(180, 3, 17, 0, 53, 28), 'Natural Causes', 'Disease', 'Nerva-Antonine', 'Principate', 'Rome, Italia', '59', '19'),
#  ('14', 'LUCIUS VERUS', 'caesar lvcivs avrelivs vervs avgvstvs', datetime.datetime(130, 12, 15, 0, 0, 28), datetime.datetime(169, 3, 15, 0, 0, 28), 'Rome', 'Italia', 'Birthright', datetime.datetime(161, 3, 7, 0, 53, 28), datetime.datetime(169, 3, 15, 0, 53, 28), 'Natural Causes', 'Disease', 'Nerva-Antonine', 'Principate', 'Rome, Italia', '39', '8'),
#  ('15', 'COMMODUS', 'caesar marcvs avrelivs commodvs antoninvs avgvstvs', datetime.datetime(161, 8, 31, 0, 0, 28), datetime.datetime(192, 12, 31, 0, 0, 28), 'Lanuvium', 'Italia', 'Birthright', datetime.datetime(177, 1, 1, 0, 53, 28), datetime.datetime(192, 12, 31, 0, 53, 28), 'Assassination', 'Praetorian Guard', 'Nerva-Antonine', 'Principate', 'Lanuvium, Italia', '31', '15'),
#  ('19', 'CARACALLA', 'caesar marcvs avrelivs severvs antoninvs pivs avgvstvs', datetime.datetime(188, 4, 4, 0, 0, 28), datetime.datetime(217, 4, 8, 0, 0, 28), 'Lugdunum', 'Gallia Lugdunensis', 'Birthright', datetime.datetime(198, 1, 1, 0, 53, 28), datetime.datetime(217, 4, 8, 0, 53, 28), 'Assassination', 'Other Emperor', 'Severan', 'Principate', 'Lugdunum, Gallia Lugdunensis', '29', '19'),
#  ('20', 'GETA', 'caesar pvblivs septimivs geta avgvstus', datetime.datetime(189, 3, 7, 0, 0, 28), datetime.datetime(211, 12, 19, 0, 0, 28), 'Rome', 'Italia', 'Birthright', datetime.datetime(209, 1, 1, 0, 53, 28), datetime.datetime(211, 12, 26, 0, 53, 28), 'Assassination', 'Other Emperor', 'Severan', 'Principate', 'Rome, Italia', '22', '2'),
#  ('21', 'MACRINUS', 'marcvs opellivs severvs macrinvs avgvstvs pivs felix', datetime.datetime(165, 1, 1, 0, 0, 28), datetime.datetime(218, 6, 8, 0, 0, 28), 'Iol Caesarea', 'Mauretania', 'Seized Power', datetime.datetime(217, 4, 11, 0, 53, 28), datetime.datetime(218, 6, 8, 0, 53, 28), 'Execution', 'Other Emperor', 'Severan', 'Principate', 'Iol Caesarea, Mauretania', '53', '1'),
#  ('60', 'JOVIAN', 'caesar flavivs iovianvs avgvstvs', datetime.datetime(331, 1, 1, 0, 0, 28), datetime.datetime(364, 2, 17, 0, 0, 28), 'Singidunum', 'Moesia', 'Appointment by Army', datetime.datetime(363, 6, 26, 0, 53, 28), datetime.datetime(364, 2, 17, 0, 53, 28), 'Natural Causes', 'Fire', 'Constantinian', 'Dominate', 'Singidunum, Moesia', '33', '1'),
#  ('61', 'VALENTINIAN I', 'flavivs valentinianvs avgvstvs', datetime.datetime(321, 7, 3, 0, 0, 28), datetime.datetime(375, 11, 17, 0, 0, 28), 'Cibalae', 'Pannonia', 'Election', datetime.datetime(364, 2, 26, 0, 53, 28), datetime.datetime(375, 11, 17, 0, 53, 28), 'Natural Causes', 'Aneurism', 'Valentinian', 'Dominate', 'Cibalae, Pannonia', '54', '11'),
#  ('62', 'VALENS', 'flavivs ivlivs valens avgvstvs', datetime.datetime(328, 1, 1, 0, 0, 28), datetime.datetime(378, 8, 9, 0, 0, 28), 'Cibalae', 'Pannonia', 'Birthright', datetime.datetime(364, 3, 28, 0, 53, 28), datetime.datetime(378, 8, 9, 0, 53, 28), 'Died in Battle', 'Opposing Army', 'Valentinian', 'Dominate', 'Cibalae, Pannonia', '50', '14'),
#  ('63', 'GRATIAN', 'flavivs gratianvs avgvstvs', datetime.datetime(359, 4, 18, 0, 0, 28), datetime.datetime(383, 8, 25, 0, 0, 28), 'Sirmium', 'Pannonia', 'Birthright', datetime.datetime(367, 8, 4, 0, 53, 28), datetime.datetime(383, 8, 25, 0, 53, 28), 'Assassination', 'Own Army', 'Valentinian', 'Dominate', 'Sirmium, Pannonia', '24', '16'),
#  ('64', 'VALENTINIAN II', 'flavivs valentinianvs invictvs avgvstvs', datetime.datetime(371, 1, 1, 0, 0, 28), datetime.datetime(392, 5, 15, 0, 0, 28), 'Milan', 'Italia', 'Birthright', datetime.datetime(375, 11, 17, 0, 53, 28), datetime.datetime(392, 5, 15, 0, 53, 28), 'Suicide', 'Unknown', 'Valentinian', 'Dominate', 'Milan, Italia', '21', '17'),
#  ('65', 'THEODOSIUS I', 'flavivs theodosivs avgvstvs', datetime.datetime(347, 1, 11, 0, 0, 28), datetime.datetime(395, 1, 17, 0, 0, 28), 'Cauca', 'Hispania', 'Birthright', datetime.datetime(379, 1, 1, 0, 53, 28), datetime.datetime(395, 1, 17, 0, 53, 28), 'Natural Causes', 'Disease', 'Theodosian', 'Dominate', 'Cauca, Hispania', '48', '16'),
#  ('67', 'VALENS', 'flavivs ivlivs valens avgvstvs', datetime.datetime(328, 1, 1, 0, 0, 28), datetime.datetime(378, 8, 9, 0, 0, 28), 'Cibalae', 'Pannonia', 'Birthright', datetime.datetime(364, 3, 28, 0, 53, 28), datetime.datetime(378, 8, 9, 0, 53, 28), 'Died in Battle', 'Opposing Army', 'Valentinian', 'Dominate', 'Cibalae, Pannonia', '50', '14'),
#  ('66', 'MAXIMINUS II', 'caesar galerivs valerivs maximinvs avgvstvs', datetime.datetime(270, 11, 20, 0, 0, 28), datetime.datetime(313, 8, 1, 0, 0, 28), 'Unknown', 'Dacia Aureliana', 'Birthright', datetime.datetime(311, 5, 1, 0, 53, 28), datetime.datetime(313, 8, 1, 0, 53, 28), 'Execution', 'Other Emperor', 'Constantinian', 'Dominate', 'Unknown, Dacia Aureliana', '43', '2'),
#  ('28', 'GORDIAN III', 'caesar marcvs antonivs gordianvs avgvstvs', datetime.datetime(225, 1, 20, 0, 0, 28), datetime.datetime(244, 2, 11, 0, 0, 28), 'Rome', 'Italia', 'Appointment by Senate', datetime.datetime(238, 4, 22, 0, 53, 28), datetime.datetime(244, 2, 11, 0, 53, 28), 'Died in Battle', 'Opposing Army', 'Gordian', 'Principate', 'Rome, Italia', '19', '6'),
#  ('30', 'PHILIP I', 'caesar marcvs ivlivs philippvs avgvstvs', datetime.datetime(204, 1, 1, 0, 0, 28), datetime.datetime(249, 10, 1, 0, 0, 28), 'Shahba', 'Syria', 'Seized Power', datetime.datetime(244, 2, 14, 0, 53, 28), datetime.datetime(249, 10, 1, 0, 53, 28), 'Execution', 'Other Emperor', 'Gordian', 'Principate', 'Shahba, Syria', '45', '5'),
#  ('31', 'TRAJAN DECIUS', 'caesar gaivs messivs qvintvs traianvs decivs avgvstvs', datetime.datetime(201, 1, 1, 0, 0, 28), datetime.datetime(251, 6, 15, 0, 0, 28), 'Budalia', 'Pannonia Inferior', 'Appointment by Army', datetime.datetime(249, 10, 1, 0, 53, 28), datetime.datetime(251, 6, 15, 0, 53, 28), 'Died in Battle', 'Opposing Army', 'Gordian', 'Principate', 'Budalia, Pannonia Inferior', '50', '2'),
#  ('32', 'TREBONIANUS GALLUS', 'caesar gaivs vibivs trebonianvs gallvs avgvstvs', datetime.datetime(206, 1, 1, 0, 0, 28), datetime.datetime(253, 8, 15, 0, 0, 28), 'Unknown', 'Italia', 'Appointment by Army', datetime.datetime(251, 6, 15, 0, 53, 28), datetime.datetime(253, 8, 15, 0, 53, 28), 'Assassination', 'Other Emperor', 'Gordian', 'Principate', 'Unknown, Italia', '47', '2'),
#  ('34', 'AEMILIAN', 'caesar marcvs aemilivs aemilianvs avgvstvs', datetime.datetime(207, 1, 1, 0, 0, 28), datetime.datetime(253, 10, 15, 0, 0, 28), 'Unknown', 'Africa', 'Appointment by Army', datetime.datetime(253, 8, 15, 0, 53, 28), datetime.datetime(253, 10, 15, 0, 53, 28), 'Assassination', 'Other Emperor', 'Gordian', 'Principate', 'Unknown, Africa', '46', '0'),
#  ('0', 'CALIGULA', 'gaivs ivlivs caesar avgvstvs germanicvs', datetime.datetime(12, 8, 31, 0, 0, 28), datetime.datetime(41, 1, 24, 0, 0, 28), 'Antitum', 'Italia', 'Birthright', datetime.datetime(37, 3, 18, 0, 53, 28), datetime.datetime(41, 1, 24, 0, 53, 28), 'Assassination', 'Senate', 'Julio-Claudian', 'Principate', 'Antitum, Italia', '29', '4'),
#  ('1', 'CLAUDIUS', 'tiberivs clavdivs caesar avgvstvs germanicvs', datetime.datetime(9, 8, 1, 0, 0, 28), datetime.datetime(54, 10, 13, 0, 0, 28), 'Lugdunum', 'Gallia Lugdunensis', 'Birthright', datetime.datetime(41, 1, 25, 0, 53, 28), datetime.datetime(54, 10, 13, 0, 53, 28), 'Assassination', 'Wife', 'Julio-Claudian', 'Principate', 'Lugdunum, Gallia Lugdunensis', '45', '13'),
#  ('23', 'SEVERUS ALEXANDER', 'caesar marcvs avrelivs severvs alexander avgvstvs', datetime.datetime(208, 10, 1, 0, 0, 28), datetime.datetime(235, 3, 18, 0, 0, 28), 'Arca Caesarea', 'Syria', 'Birthright', datetime.datetime(222, 3, 13, 0, 53, 28), datetime.datetime(235, 3, 18, 0, 53, 28), 'Assassination', 'Own Army', 'Severan', 'Principate', 'Arca Caesarea, Syria', '27', '13'),
#  ('33', 'HOSTILIAN', 'caesar caivs valens hostilianvs messivs qvintvs avgvstvs', datetime.datetime(230, 1, 1, 0, 0, 28), datetime.datetime(251, 10, 1, 0, 0, 28), 'Sirmium', 'Pannonia', 'Birthright', datetime.datetime(251, 6, 15, 0, 53, 28), datetime.datetime(251, 10, 1, 0, 53, 28), 'Natural Causes', 'Disease', 'Gordian', 'Principate', 'Sirmium, Pannonia', '21', '0'),
#  ('37', 'CLAUDIUS GOTHICUS', 'caesar marcvs avrelivs clavdivs avgvstvs', datetime.datetime(213, 5, 10, 0, 0, 28), datetime.datetime(270, 1, 15, 0, 0, 28), 'Sirmium', 'Pannonia', 'Seized Power', datetime.datetime(268, 9, 15, 0, 53, 28), datetime.datetime(270, 1, 15, 0, 53, 28), 'Natural Causes', 'Disease', 'Gordian', 'Principate', 'Sirmium, Pannonia', '57', '2'),
#  ('22', 'ELAGABALUS', 'marcvs avrelivs antoninvs avgvstvs', datetime.datetime(203, 1, 1, 0, 0, 28), datetime.datetime(222, 3, 11, 0, 0, 28), 'Emesa', 'Syria', 'Birthright', datetime.datetime(218, 6, 8, 0, 53, 28), datetime.datetime(222, 3, 11, 0, 53, 28), 'Assassination', 'Praetorian Guard', 'Severan', 'Principate', 'Emesa, Syria', '19', '4'),
#  ('39', 'AURELIAN', 'caesar lvcivs domitivs avrelianvs avgvstvs', datetime.datetime(214, 9, 9, 0, 0, 28), datetime.datetime(275, 9, 15, 0, 0, 28), 'Sirmium', 'Pannonia', 'Appointment by Army', datetime.datetime(270, 9, 15, 0, 53, 28), datetime.datetime(275, 9, 15, 0, 53, 28), 'Assassination', 'Praetorian Guard', 'Gordian', 'Principate', 'Sirmium, Pannonia', '61', '5'),
#  ('40', 'TACITUS', 'caesar marcvs clavdivs\xa0tacitvs avgvstvs', datetime.datetime(200, 1, 1, 0, 0, 28), datetime.datetime(276, 6, 15, 0, 0, 28), 'Interamna Nahars', 'Italia', 'Appointment by Senate', datetime.datetime(275, 9, 25, 0, 53, 28), datetime.datetime(276, 6, 15, 0, 53, 28), 'Natural Causes', 'Disease', 'Gordian', 'Principate', 'Interamna Nahars, Italia', '76', '1'),
#  ('24', 'MAXIMINUS I', 'caesar gaivs ivlivs vervs maximinvs avgvstvs', datetime.datetime(173, 1, 1, 0, 0, 28), datetime.datetime(238, 6, 15, 0, 0, 28), 'Unknown', 'Thrace', 'Appointment by Praetorian Guard', datetime.datetime(235, 3, 20, 0, 53, 28), datetime.datetime(238, 6, 15, 0, 53, 28), 'Assassination', 'Praetorian Guard', 'Gordian', 'Principate', 'Unknown, Thrace', '65', '3'),
#  ('54', 'MAXIMINUS II', 'caesar galerivs valerivs maximinvs avgvstvs', datetime.datetime(270, 11, 20, 0, 0, 28), datetime.datetime(313, 8, 1, 0, 0, 28), 'Unknown', 'Dacia Aureliana', 'Birthright', datetime.datetime(311, 5, 1, 0, 53, 28), datetime.datetime(313, 8, 1, 0, 53, 28), 'Execution', 'Other Emperor', 'Constantinian', 'Dominate', 'Unknown, Dacia Aureliana', '43', '2'),
#  ('56', 'CONSTANS', 'caesar flavivs ivlivs constans avgvstvs', datetime.datetime(320, 1, 1, 0, 0, 28), datetime.datetime(350, 2, 14, 0, 0, 28), 'Unknown', 'Moesia', 'Birthright', datetime.datetime(337, 5, 22, 0, 53, 28), datetime.datetime(350, 2, 14, 0, 53, 28), 'Assassination', 'Usurper', 'Constantinian', 'Dominate', 'Unknown, Moesia', '30', '13'),
#  ('53', 'LUCINIUS I', 'caesar gaivs valerivs licinivs avgvstvs', datetime.datetime(250, 1, 1, 0, 0, 28), datetime.datetime(325, 3, 1, 0, 0, 28), 'Felix Romuliana', 'Moesia Superior', 'Birthright', datetime.datetime(308, 11, 11, 0, 53, 28), datetime.datetime(324, 9, 18, 0, 53, 28), 'Execution', 'Other Emperor', 'Constantinian', 'Dominate', 'Felix Romuliana, Moesia Superior', '75', '16'),
#  ('55', 'CONSTANTINE II', 'caesar flavivs clavdivs constantinvs avgvstvs', datetime.datetime(316, 2, 1, 0, 0, 28), datetime.datetime(340, 1, 1, 0, 0, 28), 'Arelate', 'Gallia Narbonensis', 'Birthright', datetime.datetime(337, 5, 22, 0, 53, 28), datetime.datetime(340, 1, 1, 0, 53, 28), 'Execution', 'Other Emperor', 'Constantinian', 'Dominate', 'Arelate, Gallia Narbonensis', '24', '3'),
#  ('57', 'CONSANTIUS II', 'caesar flavivs ivlivs constantivs avgvstvs', datetime.datetime(317, 8, 7, 0, 0, 28), datetime.datetime(361, 11, 3, 0, 0, 28), 'Sirmium', 'Pannonia', 'Birthright', datetime.datetime(337, 5, 22, 0, 53, 28), datetime.datetime(361, 11, 3, 0, 53, 28), 'Natural Causes', 'Disease', 'Constantinian', 'Dominate', 'Sirmium, Pannonia', '44', '24'),
#  ('59', 'JULIAN', 'caesar flavivs clavdivs ivlianvs avgvstvs', datetime.datetime(331, 7, 1, 0, 0, 28), datetime.datetime(363, 6, 26, 0, 0, 28), 'Constantinople', 'Thrace', 'Birthright', datetime.datetime(360, 2, 14, 0, 53, 28), datetime.datetime(363, 6, 26, 0, 53, 28), 'Died in Battle', 'Opposing Army', 'Constantinian', 'Dominate', 'Constantinople, Thrace', '32', '3'),
#  ('16', 'PERTINAX', 'caesar pvblivs helvivs pertinax avgvstvs', datetime.datetime(126, 8, 1, 0, 0, 28), datetime.datetime(193, 3, 28, 0, 0, 28), 'Alba', 'Italia', 'Appointment by Praetorian Guard', datetime.datetime(193, 1, 1, 0, 53, 28), datetime.datetime(193, 3, 28, 0, 53, 28), 'Assassination', 'Praetorian Guard', 'Severan', 'Principate', 'Alba, Italia', '67', '0'),
#  ('17', 'DIDIUS JULIANUS', 'caesar marcvs didivs severvs ivlianvs avgvstvs', datetime.datetime(133, 1, 30, 0, 0, 28), datetime.datetime(193, 7, 1, 0, 0, 28), 'Milan', 'Italia', 'Purchase', datetime.datetime(193, 3, 28, 0, 53, 28), datetime.datetime(193, 7, 1, 0, 53, 28), 'Execution', 'Senate', 'Severan', 'Principate', 'Milan, Italia', '60', '0'),
#  ('18', 'SEPTIMUS SEVERUS', 'caesar lvcivs septimivs severvs pertinax avgvstvs', datetime.datetime(145, 4, 11, 0, 0, 28), datetime.datetime(211, 2, 4, 0, 0, 28), 'Leptis Magna', 'Libya', 'Seized Power', datetime.datetime(193, 4, 9, 0, 53, 28), datetime.datetime(211, 2, 4, 0, 53, 28), 'Natural Causes', 'Disease', 'Severan', 'Principate', 'Leptis Magna, Libya', '66', '18'),
#  ('38', 'QUINTILLUS', 'caesar marcvs avrelivs clavdivs qvintillvs avgvstvs', datetime.datetime(212, 1, 1, 0, 0, 28), datetime.datetime(270, 4, 15, 0, 0, 28), 'Sirmium', 'Pannonia', 'Birthright', datetime.datetime(270, 1, 15, 0, 53, 28), datetime.datetime(270, 4, 15, 0, 53, 28), 'Other', 'Unknown', 'Gordian', 'Principate', 'Sirmium, Pannonia', '58', '0'),
#  ('26', 'GORDIAN II', 'caesar marcvs antonivs gordianvs sempronianvs romanvs africanvs avgvstvs', datetime.datetime(192, 1, 1, 0, 0, 28), datetime.datetime(238, 4, 12, 0, 0, 28), 'Unknown', 'Unknown', 'Appointment by Senate', datetime.datetime(238, 3, 22, 0, 53, 28), datetime.datetime(238, 4, 12, 0, 53, 28), 'Execution', 'Other Emperor', 'Gordian', 'Principate', 'Unknown', '46', '0'),
#  ('27', 'BALBINUS', 'caesar decimvs caelivs calvinvs balbinvs pivs avgvstvs', datetime.datetime(178, 1, 1, 0, 0, 28), datetime.datetime(238, 7, 29, 0, 0, 28), 'Unknown', 'Unknown', 'Appointment by Senate', datetime.datetime(238, 4, 22, 0, 53, 28), datetime.datetime(238, 7, 29, 0, 53, 28), 'Assassination', 'Praetorian Guard', 'Gordian', 'Principate', 'Unknown', '60', '0'),
#  ('29', 'PUPIENUS', 'caesar marcvs clodivs pvpienvs maximvs avgvstvs', datetime.datetime(178, 1, 1, 0, 0, 28), datetime.datetime(238, 7, 29, 0, 0, 28), 'Unknown', 'Unknown', 'Appointment by Senate', datetime.datetime(238, 4, 22, 0, 53, 28), datetime.datetime(238, 7, 29, 0, 53, 28), 'Assassination', 'Praetorian Guard', 'Gordian', 'Principate', 'Unknown', '60', '0'),
#  ('36', 'GALLIENUS', 'caesar pvblivs licinivs egnativs gallienvs avgvstvs', datetime.datetime(218, 1, 1, 0, 0, 28), datetime.datetime(268, 9, 15, 0, 0, 28), 'Unknown', 'Unknown', 'Birthright', datetime.datetime(253, 10, 15, 0, 53, 28), datetime.datetime(268, 9, 15, 0, 53, 28), 'Assassination', 'Own Army', 'Gordian', 'Principate', 'Unknown', '50', '15'),
#  ('52', 'MAXENTIUS', 'marcvs avrelivs valerivs maxentivs avgvstvs', datetime.datetime(278, 1, 1, 0, 0, 28), datetime.datetime(312, 10, 8, 0, 0, 28), 'Unknown', 'Unknown', 'Birthright', datetime.datetime(306, 10, 8, 0, 53, 28), datetime.datetime(312, 10, 8, 0, 53, 28), 'Execution', 'Other Emperor', 'Constantinian', 'Dominate', 'Unknown', '34', '6'),
#  ('35', 'VALERIAN', 'caesar pvblivs licinivs valerianvs avgvstvs', datetime.datetime(195, 1, 1, 0, 0, 28), datetime.datetime(264, 1, 1, 0, 0, 28), 'Unknown', 'Unknown', 'Appointment by Army', datetime.datetime(253, 10, 15, 0, 53, 28), datetime.datetime(260, 1, 1, 0, 53, 28), 'Other', 'Opposing Army', 'Gordian', 'Principate', 'Unknown', '69', '7'),
#  ('58', 'VETRANIO', 'caesar flavivs vetranio avgvstvs', None, datetime.datetime(356, 1, 1, 0, 0, 28), 'Unknown', 'Moesia', 'Seized Power', datetime.datetime(350, 3, 1, 0, 53, 28), datetime.datetime(350, 12, 25, 0, 53, 28), 'Other', 'Unknown', 'Constantinian', 'Dominate', 'Unknown, Moesia', 'Unknown', '0'),
#  ('41', 'FLORIAN', 'caesar marcvs annivs florianvs avgvstvs', None, datetime.datetime(276, 9, 15, 0, 0, 28), 'Unknown', 'Unknown', 'Birthright', datetime.datetime(276, 6, 15, 0, 53, 28), datetime.datetime(276, 9, 15, 0, 53, 28), 'Assassination', 'Own Army', 'Gordian', 'Principate', 'Unknown', 'Unknown', '0'),
#  ('44', 'CARINUS', 'caesar marcvs avrelivs carinvs avgvstvs', None, datetime.datetime(285, 8, 1, 0, 0, 28), 'Unknown', 'Unknown', 'Birthright', datetime.datetime(283, 8, 1, 0, 53, 28), datetime.datetime(285, 8, 1, 0, 53, 28), 'Died in Battle', 'Opposing Army', 'Gordian', 'Principate', 'Unknown', 'Unknown', '2'),
#  ('48', 'SEVERUS II', 'flavivs valerivs severvs avgvstvs', None, datetime.datetime(307, 9, 16, 0, 0, 28), 'Unknown', 'Unknown', 'Appointment by Emperor', datetime.datetime(305, 5, 1, 0, 53, 28), datetime.datetime(307, 9, 16, 0, 53, 28), 'Assassination', 'Other Emperor', 'Constantinian', 'Dominate', 'Unknown', 'Unknown', '2'),
#  ('45', 'NUMERIAN', 'caesar marcvs avrelivs nvmerivs nvmerianvs avgvstvs', None, datetime.datetime(284, 11, 20, 0, 0, 28), 'Unknown', 'Unknown', 'Birthright', datetime.datetime(283, 8, 1, 0, 53, 28), datetime.datetime(284, 11, 20, 0, 53, 28), 'Other', 'Unknown', 'Gordian', 'Principate', 'Unknown', 'Unknown', '1'),
#  ('69', 'NUMERIAN', 'caesar marcvs avrelivs nvmerivs nvmerianvs avgvstvs', None, datetime.datetime(284, 11, 20, 0, 0, 28), 'Unknown', 'Unknown', 'Birthright', datetime.datetime(283, 8, 1, 0, 53, 28), datetime.datetime(284, 11, 20, 0, 53, 28), 'Other', 'Unknown', 'Gordian', 'Principate', 'Unknown', 'Unknown', '1')]

# %%
# %%sql
# postgresql:///roman
#
# ALTER TABLE emperors
# ADD COLUMN reign text
# Out:
# (psycopg2.errors.DuplicateColumn) column "reign" of relation "emperors" already exists
#
# [SQL: ALTER TABLE emperors
# ADD COLUMN reign text]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# %%sql
# postgresql:///roman
#
# ALTER TABLE emperors
# ALTER COLUMN reign_start
# type timestamp without time zone
# USING reign_start::timestamp without time zone
# Out:
# Done.
# []

# %%
# %%sql
# postgresql:///roman
#
# ALTER TABLE emperors
# ALTER COLUMN reign_end
# type timestamp without time zone
# USING reign_end::timestamp without time zone
# Out:
# Done.
# []

# %%
# %%sql
# postgresql:///roman
#
# UPDATE emperors
# SET reign = EXTRACT(YEAR FROM reign_end) - EXTRACT(YEAR FROM reign_start)
# Out:
# 71 rows affected.
# []

# %%
# %%sql
# postgresql:///roman
#
# select EXTRACT(YEAR FROM reign_end), EXTRACT(YEAR FROM reign_start), reign from emperors
# Out:
# 71 rows affected.
# [(68.0, 54.0, '14'),
#  (244.0, 238.0, '6'),
#  (249.0, 244.0, '5'),
#  (251.0, 249.0, '2'),
#  (253.0, 251.0, '2'),
#  (253.0, 253.0, '0'),
#  (69.0, 68.0, '1'),
#  (69.0, 69.0, '0'),
#  (69.0, 69.0, '0'),
#  (79.0, 69.0, '10'),
#  (238.0, 238.0, '0'),
#  (337.0, 306.0, '31'),
#  (41.0, 37.0, '4'),
#  (69.0, 69.0, '0'),
#  (81.0, 79.0, '2'),
#  (96.0, 81.0, '15'),
#  (98.0, 96.0, '2'),
#  (117.0, 98.0, '19'),
#  (161.0, 138.0, '23'),
#  (282.0, 276.0, '6'),
#  (283.0, 282.0, '1'),
#  (305.0, 284.0, '21'),
#  (305.0, 286.0, '19'),
#  (311.0, 305.0, '6'),
#  (306.0, 305.0, '1'),
#  (138.0, 117.0, '21'),
#  (180.0, 161.0, '19'),
#  (169.0, 161.0, '8'),
#  (192.0, 177.0, '15'),
#  (217.0, 198.0, '19'),
#  (211.0, 209.0, '2'),
#  (218.0, 217.0, '1'),
#  (364.0, 363.0, '1'),
#  (375.0, 364.0, '11'),
#  (378.0, 364.0, '14'),
#  (383.0, 367.0, '16'),
#  (392.0, 375.0, '17'),
#  (395.0, 379.0, '16'),
#  (378.0, 364.0, '14'),
#  (313.0, 311.0, '2'),
#  (41.0, 37.0, '4'),
#  (54.0, 41.0, '13'),
#  (235.0, 222.0, '13'),
#  (251.0, 251.0, '0'),
#  (270.0, 268.0, '2'),
#  (222.0, 218.0, '4'),
#  (275.0, 270.0, '5'),
#  (276.0, 275.0, '1'),
#  (238.0, 235.0, '3'),
#  (313.0, 311.0, '2'),
#  (350.0, 337.0, '13'),
#  (324.0, 308.0, '16'),
#  (340.0, 337.0, '3'),
#  (361.0, 337.0, '24'),
#  (363.0, 360.0, '3'),
#  (193.0, 193.0, '0'),
#  (193.0, 193.0, '0'),
#  (211.0, 193.0, '18'),
#  (270.0, 270.0, '0'),
#  (238.0, 238.0, '0'),
#  (238.0, 238.0, '0'),
#  (238.0, 238.0, '0'),
#  (268.0, 253.0, '15'),
#  (312.0, 306.0, '6'),
#  (260.0, 253.0, '7'),
#  (350.0, 350.0, '0'),
#  (276.0, 276.0, '0'),
#  (285.0, 283.0, '2'),
#  (307.0, 305.0, '2'),
#  (284.0, 283.0, '1'),
#  (284.0, 283.0, '1')]

# %%
# %%sql
# postgresql:///roman
#
# UPDATE emperors
# SET cause = 'Other'
# where cause <> 'Assassination'
# and cause <> 'Natural Causes'
# and cause <> 'Execution'
# and cause <> 'Died in Battle'
# and cause <> 'Suicide'
# Out:
# 5 rows affected.
# []

# %%
# %%sql
# postgresql:///roman
#
# SELECT DISTINCT name, full_name, birthplace, age, reign, cause as cod, era
# FROM emperors
# order by name asc
# Out:
# 66 rows affected.
# [('AEMILIAN', 'caesar marcvs aemilivs aemilianvs avgvstvs', 'Unknown, Africa', '46', '0', 'Assassination', 'Principate'),
#  ('ANTONIUS PIUS', 'caesar titvs aelivs hadrianvs antoninvs avgvstvs pivs', 'Lanuvium, Italia', '75', '23', 'Natural Causes', 'Principate'),
#  ('AURELIAN', 'caesar lvcivs domitivs avrelianvs avgvstvs', 'Sirmium, Pannonia', '61', '5', 'Assassination', 'Principate'),
#  ('BALBINUS', 'caesar decimvs caelivs calvinvs balbinvs pivs avgvstvs', 'Unknown', '60', '0', 'Assassination', 'Principate'),
#  ('CALIGULA', 'gaivs ivlivs caesar avgvstvs germanicvs', 'Antitum, Italia', '29', '4', 'Assassination', 'Principate'),
#  ('CARACALLA', 'caesar marcvs avrelivs severvs antoninvs pivs avgvstvs', 'Lugdunum, Gallia Lugdunensis', '29', '19', 'Assassination', 'Principate'),
#  ('CARINUS', 'caesar marcvs avrelivs carinvs avgvstvs', 'Unknown', 'Unknown', '2', 'Died in Battle', 'Principate'),
#  ('CARUS', 'caesar marcvs avrelivs carvs avgvstvs', 'Narbo, Gallia Narbonensis', '53', '1', 'Natural Causes', 'Principate'),
#  ('CLAUDIUS', 'tiberivs clavdivs caesar avgvstvs germanicvs', 'Lugdunum, Gallia Lugdunensis', '45', '13', 'Assassination', 'Principate'),
#  ('CLAUDIUS GOTHICUS', 'caesar marcvs avrelivs clavdivs avgvstvs', 'Sirmium, Pannonia', '57', '2', 'Natural Causes', 'Principate'),
#  ('COMMODUS', 'caesar marcvs avrelivs commodvs antoninvs avgvstvs', 'Lanuvium, Italia', '31', '15', 'Assassination', 'Principate'),
#  ('CONSANTIUS II', 'caesar flavivs ivlivs constantivs avgvstvs', 'Sirmium, Pannonia', '44', '24', 'Natural Causes', 'Dominate'),
#  ('CONSTANS', 'caesar flavivs ivlivs constans avgvstvs', 'Unknown, Moesia', '30', '13', 'Assassination', 'Dominate'),
#  ('CONSTANTINE II', 'caesar flavivs clavdivs constantinvs avgvstvs', 'Arelate, Gallia Narbonensis', '24', '3', 'Execution', 'Dominate'),
#  ('CONSTANTINE THE GREAT', 'caesar flavivs valerivs avrelivs constantinvs avgvstvs', 'Naissus, Moesia Superior', '65', '31', 'Natural Causes', 'Dominate'),
#  ('CONSTANTIUS I', 'caesar gaivs flavivs valerivs constantivs avgvstvs', 'Dardania, Moesia', '56', '1', 'Natural Causes', 'Dominate'),
#  ('DIDIUS JULIANUS', 'caesar marcvs didivs severvs ivlianvs avgvstvs', 'Milan, Italia', '60', '0', 'Execution', 'Principate'),
#  ('DIOCLETIAN', 'caesar gaivs avrelivs valerivs diocletianvs avgvstvs', 'Salona, Dalmatian', '67', '21', 'Natural Causes', 'Dominate'),
#  ('DOMITIAN', 'titvs flavivs caesar domitianvs avgvstvs', 'Rome, Italia', '45', '15', 'Assassination', 'Principate'),
#  ('ELAGABALUS', 'marcvs avrelivs antoninvs avgvstvs', 'Emesa, Syria', '19', '4', 'Assassination', 'Principate'),
#  ('FLORIAN', 'caesar marcvs annivs florianvs avgvstvs', 'Unknown', 'Unknown', '0', 'Assassination', 'Principate'),
#  ('GALBA', 'servivs svlpicivs galba caesar avgvstvs', 'Terracina, Italia', '67', '1', 'Assassination', 'Principate'),
#  ('GALERIUS', 'caesar galerivs valerivs maximianvs avgvstvs', 'Romuliana, Moesia Superior', '51', '6', 'Natural Causes', 'Dominate'),
#  ('GALLIENUS', 'caesar pvblivs licinivs egnativs gallienvs avgvstvs', 'Unknown', '50', '15', 'Assassination', 'Principate'),
#  ('GETA', 'caesar pvblivs septimivs geta avgvstus', 'Rome, Italia', '22', '2', 'Assassination', 'Principate'),
#  ('GORDIAN I', 'caesar marcvs antonivs gordianvs sempronianvs africanvs avgvstvs', 'Unknown, Phrygia', '79', '0', 'Suicide', 'Principate'),
#  ('GORDIAN II', 'caesar marcvs antonivs gordianvs sempronianvs romanvs africanvs avgvstvs', 'Unknown', '46', '0', 'Execution', 'Principate'),
#  ('GORDIAN III', 'caesar marcvs antonivs gordianvs avgvstvs', 'Rome, Italia', '19', '6', 'Died in Battle', 'Principate'),
#  ('GRATIAN', 'flavivs gratianvs avgvstvs', 'Sirmium, Pannonia', '24', '16', 'Assassination', 'Dominate'),
#  ('HADRIAN', 'caesar pvblivs aelivs traianvs hadrianvs avgvstvs', 'Italica, Hispania Baetica', '62', '21', 'Natural Causes', 'Principate'),
#  ('HOSTILIAN', 'caesar caivs valens hostilianvs messivs qvintvs avgvstvs', 'Sirmium, Pannonia', '21', '0', 'Natural Causes', 'Principate'),
#  ('JOVIAN', 'caesar flavivs iovianvs avgvstvs', 'Singidunum, Moesia', '33', '1', 'Natural Causes', 'Dominate'),
#  ('JULIAN', 'caesar flavivs clavdivs ivlianvs avgvstvs', 'Constantinople, Thrace', '32', '3', 'Died in Battle', 'Dominate'),
#  ('LUCINIUS I', 'caesar gaivs valerivs licinivs avgvstvs', 'Felix Romuliana, Moesia Superior', '75', '16', 'Execution', 'Dominate'),
#  ('LUCIUS VERUS', 'caesar lvcivs avrelivs vervs avgvstvs', 'Rome, Italia', '39', '8', 'Natural Causes', 'Principate'),
#  ('MACRINUS', 'marcvs opellivs severvs macrinvs avgvstvs pivs felix', 'Iol Caesarea, Mauretania', '53', '1', 'Execution', 'Principate'),
#  ('MARCUS AURELIUS', 'caesar marcvs avrelivs antoninvs avgvstvs', 'Rome, Italia', '59', '19', 'Natural Causes', 'Principate'),
#  ('MAXENTIUS', 'marcvs avrelivs valerivs maxentivs avgvstvs', 'Unknown', '34', '6', 'Execution', 'Dominate'),
#  ('MAXIMIAN', 'caesar marcvs avrelivs valerivs maximianvs avgvstvs', 'Sirmium, Pannonia', '60', '19', 'Suicide', 'Dominate'),
#  ('MAXIMINUS I', 'caesar gaivs ivlivs vervs maximinvs avgvstvs', 'Unknown, Thrace', '65', '3', 'Assassination', 'Principate'),
#  ('MAXIMINUS II', 'caesar galerivs valerivs maximinvs avgvstvs', 'Unknown, Dacia Aureliana', '43', '2', 'Execution', 'Dominate'),
#  ('NERO', 'nero clavdivs caesar avgvstvs germanicvs', 'Antitum, Italia', '31', '14', 'Suicide', 'Principate'),
#  ('NERVA', 'marcvs cocceivs nerva caesar avgvstvs', 'Narni, Italia', '68', '2', 'Natural Causes', 'Principate'),
#  ('NUMERIAN', 'caesar marcvs avrelivs nvmerivs nvmerianvs avgvstvs', 'Unknown', 'Unknown', '1', 'Other', 'Principate'),
#  ('OTHO', 'marcvs salvivs otho caesar avgvstvs', 'Terentinum, Italia', '37', '0', 'Suicide', 'Principate'),
#  ('PERTINAX', 'caesar pvblivs helvivs pertinax avgvstvs', 'Alba, Italia', '67', '0', 'Assassination', 'Principate'),
#  ('PHILIP I', 'caesar marcvs ivlivs philippvs avgvstvs', 'Shahba, Syria', '45', '5', 'Execution', 'Principate'),
#  ('PROBUS', 'caesar marcvs avrelivs probvs avgvstvs', 'Sirmium, Pannonia', '50', '6', 'Assassination', 'Principate'),
#  ('PUPIENUS', 'caesar marcvs clodivs pvpienvs maximvs avgvstvs', 'Unknown', '60', '0', 'Assassination', 'Principate'),
#  ('QUINTILLUS', 'caesar marcvs avrelivs clavdivs qvintillvs avgvstvs', 'Sirmium, Pannonia', '58', '0', 'Other', 'Principate'),
#  ('SEPTIMUS SEVERUS', 'caesar lvcivs septimivs severvs pertinax avgvstvs', 'Leptis Magna, Libya', '66', '18', 'Natural Causes', 'Principate'),
#  ('SEVERUS ALEXANDER', 'caesar marcvs avrelivs severvs alexander avgvstvs', 'Arca Caesarea, Syria', '27', '13', 'Assassination', 'Principate'),
#  ('SEVERUS II', 'flavivs valerivs severvs avgvstvs', 'Unknown', 'Unknown', '2', 'Assassination', 'Dominate'),
#  ('TACITUS', 'caesar marcvs clavdivs\xa0tacitvs avgvstvs', 'Interamna Nahars, Italia', '76', '1', 'Natural Causes', 'Principate'),
#  ('THEODOSIUS I', 'flavivs theodosivs avgvstvs', 'Cauca, Hispania', '48', '16', 'Natural Causes', 'Dominate'),
#  ('TITUS', 'titvs flavivs caesar vespasianvs avgvstvs', 'Rome, Italia', '42', '2', 'Natural Causes', 'Principate'),
#  ('TRAJAN', 'caesar marcvs vlpivs nerva traianvs avgvstvs', 'Italica, Hispania Baetica', '64', '19', 'Natural Causes', 'Principate'),
#  ('TRAJAN DECIUS', 'caesar gaivs messivs qvintvs traianvs decivs avgvstvs', 'Budalia, Pannonia Inferior', '50', '2', 'Died in Battle', 'Principate'),
#  ('TREBONIANUS GALLUS', 'caesar gaivs vibivs trebonianvs gallvs avgvstvs', 'Unknown, Italia', '47', '2', 'Assassination', 'Principate'),
#  ('VALENS', 'flavivs ivlivs valens avgvstvs', 'Cibalae, Pannonia', '50', '14', 'Died in Battle', 'Dominate'),
#  ('VALENTINIAN I', 'flavivs valentinianvs avgvstvs', 'Cibalae, Pannonia', '54', '11', 'Natural Causes', 'Dominate'),
#  ('VALENTINIAN II', 'flavivs valentinianvs invictvs avgvstvs', 'Milan, Italia', '21', '17', 'Suicide', 'Dominate'),
#  ('VALERIAN', 'caesar pvblivs licinivs valerianvs avgvstvs', 'Unknown', '69', '7', 'Other', 'Principate'),
#  ('VESPASIAN', 'titvs flavivs caesar vespasianvs avgvstvs', 'Falacrine, Italia', '70', '10', 'Natural Causes', 'Principate'),
#  ('VETRANIO', 'caesar flavivs vetranio avgvstvs', 'Unknown, Moesia', 'Unknown', '0', 'Other', 'Dominate'),
#  ('VITELLIUS', 'avlvs vitellivs germanicvs avgvstvs', 'Rome, Italia', '54', '0', 'Assassination', 'Principate')]
